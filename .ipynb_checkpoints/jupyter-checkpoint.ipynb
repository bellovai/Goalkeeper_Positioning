# %% [markdown]
# ### Import

# %%
# Import packages
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import os
from scipy.stats import pearsonr 
from statistics import mean
from mplsoccer import VerticalPitch
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# Import sklearn packages
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### Used Code Snippets
#
# Intersection of line and circle: https://stackoverflow.com/questions/30844482/what-is-most-efficient-way-to-find-the-intersection-of-a-line-and-a-circle-in-py
#
# Plot coordinate system: https://pygmalion.nitri.org/cartesian-coordinates-with-matplotlib-1263.html
#
# From scatter plot to heatmap: https://stackoverflow.com/questions/2369492/generate-a-heatmap-in-matplotlib-using-a-scatter-data-set/59920744#59920744

# %% [markdown]
# ### Configuration

# %% [markdown]
# Define settings:

# %%
# Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# Define constant variables in upper cases:

# %%
# Directory with all event files
DIRECTORY = '/Users/gian-andrea/Documents/Masterarbeit (offline)/statsbomb360-euro2020/events/'

# Filepath to one event file
EVENTPATH = DIRECTORY + '3788745.json'

# Filepath to one match file
MATCHPATH = '/Users/gian-andrea/Documents/Masterarbeit (offline)/statsbomb360-euro2020/matches.json'

# Gk reach
GOALKEEPER_REACH = 3.12

# Horizontal pitch positions
x_LH, y_LH = 120, 44   # Left goalpost
x_RH , y_RH = 120, 36  # Right goalpost
x_MH, y_MH = 120, 40   # Goal middle
x_OH, y_OH = 117.6, 40 # Orange point

# Vertical pitch positions
x_LV, y_LV = 36, 0      # Left goalpost
x_RV , y_RV = 44, 0     # Right goalpost
x_MV, y_MV = 40, 0      # Goal middle
x_SV, y_SV = 50, 20     # Shot position
x_GKV, y_GKV = 41.75, 3 # Gk position

# List with all togkp model names
LS_TOGKP_MODEL_NAMES = ['', '_avg', '_geo', '_line', '_arc', '_bisector', '_ml']

# List with all ml model names
LS_ML_MODEL_NAMES = [
    DecisionTreeRegressor(), 
    RandomForestRegressor(random_state = 0), 
    LinearRegression(), 
    KNeighborsRegressor()
]

# %% [markdown]
# ### Support Methods

# %%
# Find points at which circle intersects line-segment (can happen at 0, 1, or 2 points)
def circle_line_segment_intersection(pt1, full_line=True, tangent_tol=1e-9):
    
    # pt1: x-/y-coordinates of first point of segment
    # full_line: True to find intersections along full line (not just in segment), False to find intersections within segment
    # tangent_tol: Numerical tolerance at which intersections are close enough to be tangent
    
    circle_center = (120, 40) # x-/y-coordinates of circle center
    circle_radius = 4         # radius of circle
    pt2 = (120, 40)           # x-/y-coordinates of second point of segment
    
    (p1x, p1y), (p2x, p2y), (cx, cy) = pt1, pt2, circle_center
    (x1, y1), (x2, y2) = (p1x - cx, p1y - cy), (p2x - cx, p2y - cy)
    dx, dy = (x2 - x1), (y2 - y1)
    dr = (dx ** 2 + dy ** 2)**.5
    big_d = x1 * y2 - x2 * y1
    discriminant = circle_radius ** 2 * dr ** 2 - big_d ** 2

    # No intersection between circle and line
    if discriminant < 0:
        return []
    # There may be 0, 1, or 2 intersections with the segment
    else:
        intersections = [
            (cx + (big_d * dy + sign * (-1 if dy < 0 else 1) * dx * discriminant**.5) / dr ** 2,
             cy + (-big_d * dx + sign * abs(dy) * discriminant**.5) / dr ** 2)
            # This makes sure the order along the segment is correct
            for sign in ((1, -1) if dy < 0 else (-1, 1))]
        # If only considering the segment, filter out intersections that do not fall within the segment
        if not full_line:
            fraction_along_segment = [(xi - p1x) / dx if abs(dx) > abs(dy) else (yi - p1y) / dy for xi, yi in intersections]
            intersections = [pt for pt, frac in zip(intersections, fraction_along_segment) if 0 <= frac <= 1]
        # If line is tangent to circle, return just one point (as both intersections have same location)
        if len(intersections) == 2 and abs(discriminant) <= tangent_tol: 
            # return Sequence[Tuple[float, float]]: list of length 0, 1, or 2, where each element is a point at which circle intercepts line segment
            return [intersections[0]]
        else:
            return intersections

# %%
# Add column with distance between gk position and alternative gk position to dataframe
def distance_gk_gk_alt(df, gk_alt):
    
    # Create empty list
    ls_distance = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define two gk positions
        x_gk = df.at[row, 'x_gk']
        y_gk = df.at[row, 'y_gk']
        x_gk_alt = df.at[row, 'x_gk' + gk_alt]
        y_gk_alt = df.at[row, 'y_gk' + gk_alt]
        # Add distance between two gk positions to list
        ls_distance.append(round(math.dist([x_gk, y_gk], [x_gk_alt, y_gk_alt]), 2))
    
    # Define column name
    col_name = 'distance_gk_gk' + gk_alt
    # Add list to dataframe
    df[col_name] = ls_distance

    # Return dataframe
    return df

# %%
# Add column with distance between average gk position and alternative gk position to dataframe
def distance_gk_avg_gk_alt(df, gk_alt):
    
    # Create empty list
    ls_distance = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define two gk positions
        x_gk_avg = df.at[row, 'x_gk_avg']
        y_gk_avg = df.at[row, 'y_gk_avg']
        x_gk_alt = df.at[row, 'x_gk' + gk_alt]
        y_gk_alt = df.at[row, 'y_gk' + gk_alt]
        # Add distance between two gk positions to list
        ls_distance.append(round(math.dist([x_gk_avg, y_gk_avg], [x_gk_alt, y_gk_alt]), 2))
    
    # Define column name
    col_name = 'distance_gk_avg_gk' + gk_alt
    # Add list to dataframe
    df[col_name] = ls_distance

    # Return dataframe
    return df

# %%
# Add column with distance between any gk position and goalline to dataframe
def distance_gk_goalline(df, gk_name):
    
    # Create empty list
    ls_distance_gk_goalline = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define x of gk position
        x_gk = df.at[row, 'x_gk' + gk_name]
        # Add distance between gk position and goalline to list
        ls_distance_gk_goalline.append(120 - x_gk)
    
    # Define column name
    col_name = 'distance_gk' + gk_name + '_goalline'
    # Add list to dataframe
    df[col_name] = ls_distance_gk_goalline

    # Return dataframe
    return df

# %%
# Add column with distance between any gk position and bisector to dataframe
def distance_gk_bisector(df, gk_name):
    
    # Create empty list
    ls_distance_gk_bisector = []

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define gk position
        x_gk = df.at[row, 'x_gk' + gk_name]
        y_gk = df.at[row, 'y_gk' + gk_name]
        # Define linear equation of bisector
        m_bisector = df.at[row, 'bisector_slope']
        q_bisector = y_shot - m_bisector *x_shot
        
        # If central shot
        if m_bisector == 0:
            # Calculate intersection of two linear equations
            x_intersection = x_gk
            y_intersection = 40
        # If decentral shot
        else:
            # Define linear equation through gk position and perpendicular to bisector
            m_perpendicular = -(1/m_bisector)
            q_perpendicular = y_gk - m_perpendicular *x_gk
            # Calculate intersection of two linear equations
            y_intersection = (q_perpendicular - q_bisector*m_perpendicular/m_bisector)/(1-(m_perpendicular/m_bisector))
            x_intersection = (y_intersection-q_bisector)/m_bisector

        # Add value to list
        ls_distance_gk_bisector.append(round(math.dist([x_gk, y_gk], [x_intersection, y_intersection]), 2))
    
    # Define column name
    col_name = 'distance_gk' + gk_name +'_bisector'
    # Add list to dataframe
    df[col_name] = ls_distance_gk_bisector
    
    # Return dataframe
    return df

# %%
# Add column with distance between shot position and gk position on bisector to dataframe
def distance_reaction(df):
    
    # Create empty list
    ls_distance_reaction = []

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define gk position
        x_gk = df.at[row, 'x_gk']
        y_gk = df.at[row, 'y_gk']
        # Define linear equation of bisector
        m_bisector = df.at[row, 'bisector_slope']
        q_bisector = y_shot - m_bisector *x_shot
        
        # If central shot
        if m_bisector == 0:
            # Calculate intersection of two linear equations
            x_intersection = x_gk
            y_intersection = 40
        # If decentral shot
        else:
            # Define linear equation through gk position and perpendicular to bisector
            m_perpendicular = -(1/m_bisector)
            q_perpendicular = y_gk - m_perpendicular *x_gk
            # Calculate intersection of two linear equations
            y_intersection = (q_perpendicular - q_bisector*m_perpendicular/m_bisector)/(1-(m_perpendicular/m_bisector))
            x_intersection = (y_intersection-q_bisector)/m_bisector

        # Add value to list
        ls_distance_reaction.append(round(math.dist([x_shot, y_shot], [x_intersection, y_intersection]), 2))
    
    # Add list to dataframe
    df['distance_reaction'] = ls_distance_reaction
    
    # Return dataframe
    return df

# %%
# Add column with largest open goal width of virtual goal to dataframe
def max_open_goal(df):
    
    # Create empty list
    ls_max_open_goal = []

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define gk position
        x_gk = df.at[row, 'x_gk']
        y_gk = df.at[row, 'y_gk']
        # Define linear equation of bisector
        m_bisector = df.at[row, 'bisector_slope']
        q_bisector = y_shot - m_bisector*x_shot
        # Define linear equation from shot position to left goalpost
        m_shot_l = (y_shot - y_LH)/(x_shot - x_LH)
        q_shot_l = y_LH - m_shot_l*x_LH
        # Define linear equation from shot position to right goalpost
        m_shot_r = (y_shot - y_RH)/(x_shot - x_RH)
        q_shot_r = y_RH - m_shot_r*x_RH
        
        # If central shot
        if m_bisector == 0:
            # Calculate intersection of two linear equations
            x_intersection = x_gk
            y_intersection_l = m_shot_l*x_gk + q_shot_l
            y_intersection_r = m_shot_r*x_gk + q_shot_r
        # If decentral shot
        else:
            # Define linear equation through gk position and perpendicular to bisector
            m_perpendicular = -(1/m_bisector)
            q_perpendicular = y_gk - m_perpendicular*x_gk
            # Calculate intersection of two linear equations
            if m_shot_l == 0:
                y_intersection_l = y_shot
                x_intersection_l = (y_intersection_l - q_perpendicular)/m_perpendicular
            else:
                y_intersection_l = (q_perpendicular - q_shot_l*m_perpendicular/m_shot_l)/(1 - (m_perpendicular/m_shot_l))
                x_intersection_l = (y_intersection_l - q_shot_l)/m_shot_l
            if m_shot_r == 0:
                y_intersection_r = y_shot
                x_intersection_r = (y_intersection_r - q_perpendicular)/m_perpendicular
            else:
                y_intersection_r = (q_perpendicular - q_shot_r*m_perpendicular/m_shot_r)/(1 - (m_perpendicular/m_shot_r))
                x_intersection_r = (y_intersection_r - q_shot_r)/m_shot_r

        # Save widths
        d_l = math.dist([x_gk, y_gk], [x_intersection_l, y_intersection_l])
        d_r = math.dist([x_gk, y_gk], [x_intersection_r, y_intersection_r])
        # Add largest width to list
        if df.at[row, 'shooting_cone_without_gk'] == True:
            if y_shot >= 40:
                y_p = 44
                q_shot = q_shot_l
                m_shot = m_shot_l
            else:
                y_p = 36
                q_shot = q_shot_r
                m_shot = m_shot_r
            q_perpendicular = y_p - m_perpendicular*120
            y_intersection = (q_perpendicular - q_bisector*m_perpendicular/m_bisector)/(1 - (m_perpendicular/m_bisector))
            x_intersection = (y_intersection - q_bisector)/m_bisector
            ls_max_open_goal.append(round(2*math.dist([120, y_p], [x_intersection, y_intersection]), 2))
        elif d_l > d_r:
            ls_max_open_goal.append(round(d_l, 2))
        else:
            ls_max_open_goal.append(round(d_r, 2))
            
    # Add list to dataframe
    df['max_open_goal'] = ls_max_open_goal
    
    # Return dataframe
    return df

# %%
# Add column with ratio of distance from shot position to gk position and gk position to bisector to dataframe
def ratio_shotgk_gkbisector(df, gk_name):
    
    # Create empty list
    ls_ratio_shotgk_gkbisector = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define gk position
        x_gk = df.at[row, 'x_gk' + gk_name]
        y_gk = df.at[row, 'y_gk' + gk_name]
        # Define distance from gk position to bisector
        distance_gk_bisector = df.at[row, 'distance_gk' + gk_name + '_bisector']
        
        # Calculate value
        if distance_gk_bisector != 0:
            ratio_shotgk_gkbisector = round(math.dist([x_shot, y_shot], [x_gk, y_gk]) / distance_gk_bisector, 2)
        else:
            ratio_shotgk_gkbisector = 4030
        # Add value to list  
        ls_ratio_shotgk_gkbisector.append(ratio_shotgk_gkbisector)

    # Define column name
    col_name = 'ratio_shotgk' + gk_name + '_bisectorgk' + gk_name
    # Add list to dataframe
    df[col_name] = ls_ratio_shotgk_gkbisector

    # Return dataframe
    return df

# %%
# Put all shot positions and gk positions from one side of the pitch to the other
def mirror_shots(df):
    
    # Copy dataframe
    df = df.copy()
    # Create empty lists
    ls_y_shot_mirror = []
    ls_y_gk_mirror = []
    ls_mirror = []

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        if df.at[row, 'y_shot'] < 40:
            ls_y_shot_mirror.append(80 - df.at[row, 'y_shot'])
            ls_y_gk_mirror.append(80 - df.at[row, 'y_gk'])
            ls_mirror.append(True)
        else:
            ls_y_shot_mirror.append(df.at[row, 'y_shot'])
            ls_y_gk_mirror.append(df.at[row, 'y_gk'])
            ls_mirror.append(False)

    # Add lists to dataframe
    df['y_shot'] = ls_y_shot_mirror
    df['y_gk'] = ls_y_gk_mirror
    df['mirror'] = ls_mirror
    
    # Return dataframe
    return df

# %% [markdown]
# ### Dataframe Methods

# %%
# Create dataframe with data from all json files in directory
def create_dataframe(directory):
    
    # Create empty lists
    ls_shot = []
    ls_possession_team = []
    ls_location = []

    # Iterate over all files in directory
    for filename in os.listdir(directory):

        # Save filepath to current file
        filepath = os.path.join(directory, filename)
        # If current file has json ending
        if filename.split('.')[1] == 'json':
            # Transform current json file to dataframe
            df_file = pd.read_json(filepath)
            # Transform columns of current dataframe to lists and add them to existing lists
            ls_shot.extend(df_file['shot'].tolist())
            ls_possession_team.extend(df_file['possession_team'].tolist())
            ls_location.extend(df_file['location'].tolist())

    # Create empty dataframe and add complete lists 
    df = pd.DataFrame()
    df['shot'] = ls_shot
    df['possession_team'] = ls_possession_team
    df['location'] = ls_location

    # Return dataframe
    return df

# Apply method and display dataframe
df_all = create_dataframe(DIRECTORY)
print('Number of rows:', len(df_all))
df_all.head(1)
# Out:
# Number of rows: 192686
#   shot                 possession_team location
# 0  NaN  {'id': 776, 'name': 'Denmark'}      NaN

# %%
# Create dataframe filtered for undeflected shots from open plays
def filter_shots(df):

    # Filter dataframe for shots
    df = df.dropna().reset_index(drop = True)
    # Create empty list
    ls_delete_rows = []
    
    # Add row number of all deflected or non open play shots to list 
    for row in range(0, len(df)):
        if df.at[row, 'shot']['type']['name'] != 'Open Play' or 'deflected' in df.iloc[row]['shot']:
            ls_delete_rows.append(row)
    # Delete deflected or non open play shots from dataframe
    df.drop(ls_delete_rows, inplace = True)
    
    # Transform shot location to shot coordinates
    df['x_shot'], df['y_shot'] = zip(*df['location'])
    # Delete shot location column
    del df['location']

    # Return dataframe
    return df.reset_index(drop = True)

# Apply method and display dataframe
df_shot = filter_shots(df_all)
print('Number of rows:', len(df_shot))
df_shot.head(1)
# Out:
# Number of rows: 1174
#                                                 shot  \
# 0  {'statsbomb_xg': 0.05932782, 'end_location': [...
#
#                   possession_team  x_shot  y_shot
# 0  {'id': 776, 'name': 'Denmark'}    97.7    33.3

# %%
# Create previous dataframe with additional data
def complete_shots(df):
    
    # Create previous dataframe
    df = filter_shots(df)
    # Create empty lists
    ls_outcome = []
    ls_statsbomb_xg = []
    ls_possession_team = []
    ls_shot_body_part = []
    ls_shot_technique = []
    ls_goalkeeper = []
    ls_goalkeeper_id = []
    ls_x_shot = []
    ls_y_shot = []
    ls_x_gk = []
    ls_y_gk = []
    ls_player_locations = []

    # Iterate over all rows in dataframe
    for row in range (0, len(df)):
        
        # If current row has freeze frame
        if 'freeze_frame' in df.iloc[row]['shot']:
            
            # Reset nested player locations list
            ls_player_locations_nested = []
            # Add values to lists
            ls_outcome.append(df.iloc[row]['shot']['outcome']['name'])
            ls_statsbomb_xg.append(round(df.iloc[row]['shot']['statsbomb_xg'], 4))
            ls_possession_team.append(df.iloc[row]['possession_team']['name'])
            ls_shot_body_part.append(df.iloc[row]['shot']['body_part']['name'])
            ls_shot_technique.append(df.iloc[row]['shot']['technique']['name'])
            ls_x_shot.append(df.iloc[row]['x_shot'])
            ls_y_shot.append(df.iloc[row]['y_shot'])
            
            # Save shot information from current freeze frame
            shot = df.iloc[row]['shot']['freeze_frame']
            # Iterate over all players in freeze frame
            for i in range (0, len(shot)):
                
                # Add gk name and gk coordinates to lists
                if shot[i]['position']['name'] == 'Goalkeeper' and shot[i]['teammate'] == False:
                    ls_goalkeeper.append(shot[i]['player']['name'])
                    ls_goalkeeper_id.append(int(shot[i]['player']['id']))
                    ls_x_gk.append(shot[i]['location'][0])
                    ls_y_gk.append(shot[i]['location'][1])
                # Add remaining player locations to list
                else:
                    ls_player_locations_nested.append(shot[i]['location'])
                    
            # Add remaining player locations list or empty string to list
            if len(ls_player_locations_nested) > 0:
                ls_player_locations.append(ls_player_locations_nested)
            else:
                ls_player_locations.append('')
    
    # Create empty dataframe and add complete lists
    df = pd.DataFrame()
    df['outcome'] = ls_outcome
    df['statsbomb_xg'] = ls_statsbomb_xg
    df['possession_team'] = ls_possession_team
    df['shot_body_part'] = ls_shot_body_part
    df['shot_technique'] = ls_shot_technique
    df['goalkeeper'] = ls_goalkeeper
    df['goalkeeper_id'] = ls_goalkeeper_id
    df['x_shot'] = ls_x_shot
    df['y_shot'] = ls_y_shot
    df['x_gk'] = ls_x_gk
    df['y_gk'] = ls_y_gk
    df['player_locations'] = ls_player_locations
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_complete_shots = complete_shots(df_all)
df_complete_shots.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...

# %%
# Create previous dataframe with additional data on players in shot polygon
def polygon_players(df):
    
    # Create previous dataframe filtered for shots with coordinates from other players
    df = complete_shots(df).where(df_complete_shots['player_locations'] != '').dropna().reset_index(drop = True)
    # Create empty lists
    ls_polygon_players = []
    ls_polygon_players_count = []
        
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Reset nested polygon players list
        ls_polygon_players_nested = []
        # Iterate over all players in shot
        for i in range (0, len(df.at[row, 'player_locations'])):
            # Define point and polygon
            point = Point(df.at[row, 'player_locations'][i][0], df.at[row, 'player_locations'][i][1])
            polygon = Polygon([(df.at[row, 'x_shot'], df.at[row, 'y_shot']), (x_RH, y_RH), (x_LH, y_LH)])
            # Add points inside polygon to list
            if polygon.contains(point) == True:
                ls_polygon_players_nested.append(df.at[row, 'player_locations'][i])
        
        # Add nested polygon players list or empty string to list
        if len(ls_polygon_players_nested) > 0:
            ls_polygon_players.append(ls_polygon_players_nested)
        else:
            ls_polygon_players.append('')
        # Add polygon players count values to list    
        ls_polygon_players_count.append(len(ls_polygon_players_nested))
    
    # Add lists to dataframe
    df['polygon_players'] = ls_polygon_players
    df['polygon_players_count'] = ls_polygon_players_count
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_polygon_players = polygon_players(df_all)
df_polygon_players.head(2)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
# 1   Off T        0.0193         Denmark           Head         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
# 1  Lukáš Hrádecký           8667   107.5    36.9  117.6  39.4
#
#                                     player_locations  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
# 1  [[112.2, 39.8], [110.6, 37.6], [108.6, 35.4], ...
#
#                                      polygon_players  polygon_players_count
# 0                                                                         0
# 1  [[110.6, 37.6], [111.6, 38.6], [112.2, 38.8], ...                      4

# %%
# Create previous dataframe with shooting angle
def shooting_angle(df):
    
    # Create previous dataframe
    df = polygon_players(df)
    # Create empty list
    ls_shooting_angle = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        # Calculate slopes from shot position to goalposts
        m_r = (y_RH - df.at[row, 'y_shot'])/(x_RH - df.at[row, 'x_shot'])
        m_l = (y_LH - df.at[row, 'y_shot'])/(x_LH - df.at[row, 'x_shot'])
        # Add value to list
        ls_shooting_angle.append(round(math.degrees(abs(math.atan(m_r) - math.atan(m_l))), 4))

    # Add list to dataframe
    df['shooting_angle'] = ls_shooting_angle
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_shooting_angle = shooting_angle(df_all)
df_shooting_angle.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle
# 0                      0         18.7291

# %%
# Create previous dataframe with bisector slope
def bisector_slope(df):
    
    # Create previous dataframe
    df = shooting_angle(df)
    # Create empty list
    ls_bisector_slope = []
    
    # x_shot, y_shot = origin = shot position
    # x_RH, y_RH = point = right goalpost
    # x_r, y_r = rotated point
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
    
        # Define shot coordinates
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define half shooting angle
        ang = math.radians(df.at[row, 'shooting_angle'])/2

        # Rotate point counterclockwise by defined angle in radians around defined origin
        x_r = x_shot + math.cos(ang) * (x_RH - x_shot) - math.sin(ang) * (y_RH - y_shot)
        y_r = y_shot + math.sin(ang) * (x_RH - x_shot) + math.cos(ang) * (y_RH - y_shot)
        
        # Add value to list
        ls_bisector_slope.append(round((y_r-y_shot)/(x_r-x_shot), 4))
        
    # Add list to dataframe
    df['bisector_slope'] = ls_bisector_slope   
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_bisector_slope = bisector_slope(df_all)
df_bisector_slope.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope
# 0                      0         18.7291          0.2918

# %%
# Create previous dataframe with togkp from bisector model
def gk_bisector(df):
    
    # Create previous dataframe
    df = bisector_slope(df)
    # Create empty lists
    ls_x_gk_bisector = []
    ls_y_gk_bisector = []

    # Iterate over all rows in dataframe
    for j in range(0, len(df)):

        # Define shot position
        x_shot = df.at[j, 'x_shot']
        y_shot = df.at[j, 'y_shot']
        # Define linear equation of bisector
        m_bisector = df.at[j, 'bisector_slope']
        q_bisector = y_shot - m_bisector*x_shot
        # Define half shooting angle
        ang = math.radians(df.at[j, 'shooting_angle'])/2

        # If central shot
        if m_bisector == 0:
            x_shift = (math.cos(ang)*GOALKEEPER_REACH)/math.sin(ang)
            x_gk_bisector = x_shot + x_shift
            y_gk_bisector = y_MH
        # If decentral shot
        else:
            # Define linear equation through closer goalpost and perpendicular to bisector
            d_r = math.dist([x_shot, y_shot], [x_RH, y_RH])
            d_l = math.dist([x_shot, y_shot], [x_LH, y_LH])
            if d_r < d_l:
                y_post = y_RH
            else:
                y_post = y_LH
            x_post = x_RH
            m_post = -(1/m_bisector)
            q_post = y_post - m_post*x_post

            # Calculate intersection of two linear equations
            y_gk_bisector = (q_bisector - q_post*m_bisector/m_post)/(1 - (m_bisector/m_post))
            x_gk_bisector = (y_gk_bisector - q_post)/m_post

        # If covered length is not enough
        if math.dist([x_post, y_post], [x_gk_bisector, y_gk_bisector]) > GOALKEEPER_REACH:

            # Distance from shot position to togkp to cover gk reach
            distance = (math.cos(ang)*GOALKEEPER_REACH)/math.sin(ang)
            # Shift from shot position to togkp
            x_shift = distance/(math.sqrt(1+m_bisector*m_bisector))
            y_shift = x_shift*m_bisector
            # Calculate togkp
            x_gk_bisector = x_shot + x_shift
            y_gk_bisector = y_shot + y_shift
        
        # Add values to lists
        ls_x_gk_bisector.append(round(x_gk_bisector, 2))
        ls_y_gk_bisector.append(round(y_gk_bisector, 2))

    # Add lists to dataframe
    df['x_gk_bisector'] = ls_x_gk_bisector
    df['y_gk_bisector'] = ls_y_gk_bisector

    # Return dataframe
    return df

# Apply method and display dataframe
df_gk_bisector = gk_bisector(df_all)
df_gk_bisector.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector
# 0           38.6

# %%
# Create previous dataframe with togkp from knn model
def gk_avg(df):
    
    # Create previous dataframe
    df = gk_bisector(df)
    # Create empty lists
    ls_x_gk_avg = []
    ls_y_gk_avg = []
    
    # Iterate over all rows in dataframe
    for i in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[i, 'x_shot']
        y_shot = df.at[i, 'y_shot']
        # Create empty list
        ls_distance = []

        # Iterate over all rows in dataframe again
        for row in range(0, len(df)):
            # Define similar shot position
            x_shot_similar = df.at[row, 'x_shot']
            y_shot_similar = df.at[row, 'y_shot']
            # Add distance between shot position and similar shot position to list
            ls_distance.append(math.dist([x_shot, y_shot], [x_shot_similar, y_shot_similar]))
        # Sort indices by ascending distance values and save value 1 to 21 (i.e. don't save the smallest)
        sorted_indices = np.argsort(ls_distance).tolist()[1:21]

        # Define counter variables
        x_gk_tot = 0
        y_gk_tot = 0
        # Sum up 20 gk coordinates coordinates from 20 most similar shots
        for row in sorted_indices:
            x_gk_tot = x_gk_tot + df.at[row, 'x_gk']
            y_gk_tot = y_gk_tot + df.at[row, 'y_gk']
        # Add mean gk coordinates from 20 most similar shots to list
        ls_x_gk_avg.append(round(x_gk_tot/20, 2))
        ls_y_gk_avg.append(round(y_gk_tot/20, 2))   
        
    # Add lists to dataframe
    df['x_gk_avg'] = ls_x_gk_avg    
    df['y_gk_avg'] = ls_y_gk_avg
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_gk_avg = gk_avg(df_all)
df_gk_avg.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector  x_gk_avg  y_gk_avg
# 0           38.6    117.29     38.75

# %%
# Create previous dataframe with togkp from geometric model
def gk_geo(df):
    
    # Create previous dataframe
    df = gk_avg(df)
    # Create empty lists
    ls_x_gk_geo = []
    ls_y_gk_geo = []

#################################################################################################
    # Define orange polygons
    polygon_orange_1 = Polygon([(114, 62), (120, 62), (120, 80), (114, 80)])
    polygon_orange_2 = Polygon([(114, 0), (120, 0), (120, 18), (114, 18)])
    polygon_orange_3 = Polygon([(60, 62), (98.85, 62), (98.85, 80), (60, 80)])
    polygon_orange_4 = Polygon([(60, 0), (98.85, 0), (98.85, 18), (60, 18)])
    # Define yellow polygons
    polygon_yellow_1 = Polygon([(117.6, 44), (120, 44), (120, 62), (106.8, 62)])
    polygon_yellow_2 = Polygon([(106.8, 18), (120, 18), (120, 36), (117.6, 36)])
    # Define red polygon
    polygon_red = Polygon([(60, 18), (98.85, 18), (98.85, 0), (114, 0), (114, 18), (102, 18), (102, 33.1), (98.85, 33.1), (98.85, 46.9), (102, 46.9), (102, 62), (114, 62), (114, 80), (98.85, 80), (98.85, 62), (60, 62)])
    # Define blue polygon
    polygon_blue = Polygon([(98.85, 36.774625), (114, 39.085), (114, 40.915), (98.85, 43.225375)])
    # Define light blue polygons
    polygon_light_1 = Polygon([(98.85, 43.225375), (114, 40.915), (117.6, 44), (106.8, 62), (102, 62), (102, 48), (98.85, 48)])
    polygon_light_2 = Polygon([(102, 18), (106.8, 18), (117.6, 36), (114, 39.085), (98.85, 36.774625), (98.85, 32), (102, 32)])
#################################################################################################
        
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        # Define shot point
        point = Point(x_shot, y_shot)

        # If shot lies in orange polygon
        if polygon_orange_1.contains(point) == True or polygon_orange_2.contains(point) == True or polygon_orange_3.contains(point) == True or polygon_orange_4.contains(point) == True:
            # Define togkp
            x_gk_geo = x_OH
            y_gk_geo = y_OH

        # If shot lies in red polygon
        elif polygon_red.contains(point) == True:
            # Define linear equation of ballline
            m_ballline = (y_shot-y_MH)/(x_shot-x_MH)
            q_ballline = y_shot - m_ballline*x_shot
            # If central shot
            if m_ballline == 0:
                # Define togkp
                x_gk_geo = x_OH
                y_gk_geo = y_OH
            # If decentral shot
            else:
                # Define linear equation of gk_geo line
                if m_ballline > 0:
                    m_gk_geo = (y_RH-y_OH)/(x_RH-x_OH)
                    q_gk_geo = y_RH - m_gk_geo*x_RH
                else:
                    m_gk_geo = (y_LH-y_OH)/(x_LH-x_OH)
                    q_gk_geo = y_LH - m_gk_geo*x_LH
                # # Define togkp by calculating intersection of two linear equations
                y_gk_geo = (q_gk_geo - q_ballline*m_gk_geo/m_ballline)/(1-(m_gk_geo/m_ballline))
                x_gk_geo = (y_gk_geo-q_ballline)/m_ballline

        # If shot lies in blue polygon
        elif polygon_blue.contains(point) == True:
            # Define linear equation of ballline
            m_ballline = (y_shot-y_MH)/(x_shot-x_MH)
            q_ballline = y_shot - m_ballline*x_shot
            # Define togkp
            x_gk_geo = 114
            y_gk_geo = q_ballline + m_ballline*x_gk_geo

        # If shot lies in light blue polygon
        elif polygon_light_1.contains(point) == True or polygon_light_2.contains(point) == True:
            # Define linear equation of ballline
            m_ballline = (y_shot-40)/(x_shot-120)
            q_ballline = y_shot - m_ballline*x_shot
            # Define linear equation of gk_geo line
            if m_ballline > 0:
                m_gk_geo = (36-39.085)/(117.6-114)
                q_gk_geo = 36 - m_gk_geo*117.6
            else:
                m_gk_geo = (44-40.915)/(117.6-114)
                q_gk_geo = 44 - m_gk_geo*117.6
            # Define togkp by calculating intersection of two linear equations
            y_gk_geo = (q_gk_geo - q_ballline*m_gk_geo/m_ballline)/(1-(m_gk_geo/m_ballline))
            x_gk_geo = (y_gk_geo-q_ballline)/m_ballline

        # If shot lies in yellow polygon
        elif polygon_yellow_1.contains(point) == True or polygon_yellow_2.contains(point) == True:
            # Define linear equation of ballline
            m_ballline = (y_shot-y_MH)/(x_shot-x_MH)
            q_ballline = y_shot - m_ballline*x_shot
            # Define togkp
            if m_ballline > 0:
                y_gk_geo = y_RH
            else:
                y_gk_geo = y_LH
            # Define togkp by calculating intersection of two linear equations
            x_gk_geo = (y_gk_geo-q_ballline)/m_ballline

#################################################################################################
        # If no polygon contains point
        else:
            x_gk_geo = x_MH
            y_gk_geo = y_MH
#################################################################################################

        # Add values to lists
        ls_x_gk_geo.append(round(x_gk_geo, 2))
        ls_y_gk_geo.append(round(y_gk_geo, 2))
        
    # Add lists to dataframe
    df['x_gk_geo'] = ls_x_gk_geo
    df['y_gk_geo'] = ls_y_gk_geo

    # Return dataframe
    return df

# Apply method and display dataframe
df_gk_geo = gk_geo(df_all)
df_gk_geo.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo
# 0           38.6    117.29     38.75    117.97     39.39

# %%
# Create previous dataframe with togkp from line positioning model
def gk_line(df):
    
    # Create previous dataframe
    df = gk_geo(df)
    # Create empty lists
    ls_x_gk_line = []
    ls_y_gk_line = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):

        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']

        # If shot is further away then line
        if x_shot < 118:
            # Define linear equation of ballline
            m_ballline = (y_shot - y_MH)/(x_shot - x_MH)
            q_ballline = y_shot - m_ballline*x_shot
            # Define togkp by calculating intersection of two linear equations
            x_gk_line = 118
            y_gk_line = q_ballline + m_ballline*x_gk_line

#################################################################################################
        # If shot is not further away then line
        else:
            # Define togkp
            x_gk_line = x_MH
            y_gk_line = y_MH
#################################################################################################

        # Add values to lists
        ls_x_gk_line.append(round(x_gk_line, 2))
        ls_y_gk_line.append(round(y_gk_line, 2))
        
    # Add lists to dataframe
    df['x_gk_line'] = ls_x_gk_line
    df['y_gk_line'] = ls_y_gk_line

    # Return dataframe
    return df

# Apply method and display dataframe
df_gk_line = gk_line(df_all)
df_gk_line.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  x_gk_line  y_gk_line
# 0           38.6    117.29     38.75    117.97     39.39        118       39.4

# %%
# Create previous dataframe with togkp from gk's arc model
def gk_arc(df):
    
    # Create previous dataframe
    df = gk_line(df)
    # Create empty lists
    ls_x_gk_arc = []
    ls_y_gk_arc = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):

        # Define shot position
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']

        # Calculate intersection of linear equation with circle
        intersections = circle_line_segment_intersection((x_shot, y_shot))
        # Define togkp
        x_gk_arc = intersections[0][0]
        y_gk_arc = intersections[0][1]
        
#################################################################################################
        # If shot is not further away then intersection
        if x_shot > x_gk_arc:
            # Define gk_arc coordinates
            x_gk_arc = x_MH
            y_gk_arc = y_MH
#################################################################################################

        # Add values to lists
        ls_x_gk_arc.append(round(x_gk_arc, 2))
        ls_y_gk_arc.append(round(y_gk_arc, 2))
        
    # Add lists to dataframe
    df['x_gk_arc'] = ls_x_gk_arc
    df['y_gk_arc'] = ls_y_gk_arc

    # Return dataframe
    return df

# Apply method and display dataframe
df_gk_arc = gk_arc(df_all)
df_gk_arc.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  x_gk_line  \
# 0           38.6    117.29     38.75    117.97     39.39        118
#
#    y_gk_line  x_gk_arc  y_gk_arc
# 0       39.4    116.17     38.85

# %%
# Create previous dataframe with alternative data
def alt(df):
    
    # Create previous dataframe
    df = gk_arc(df)
    # Create empty lists
    ls_goal_angle = []
    ls_gk_angle = []
    ls_distance_shot_goal = []
    ls_distance_shot_goalline = []
    ls_distance_shot_goalcenter = []
    ls_angular_deviation = []
    ls_shooting_cone_without_gk = []
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Define variables
        x_shot = df.at[row, 'x_shot']
        y_shot = df.at[row, 'y_shot']
        x_gk = df.at[row, 'x_gk']
        y_gk = df.at[row, 'y_gk']
        x_gk_bisector = df.at[row, 'x_gk_bisector']
        y_gk_bisector = df.at[row, 'y_gk_bisector']
        m_shot_goalcenter = (y_MH-y_shot)/(x_MH-x_shot)
        m_gk_goalcenter = (x_MH-x_gk)
        m_shot_gk = (y_gk-y_shot)/(x_gk-x_shot)
        m_bisector = df.at[row, 'bisector_slope']
        if x_gk == 120:
            ls_gk_angle.append(0)
        else:
            m_gk_goalcenter = (y_MH-y_gk)/(x_MH-x_gk)
            ls_gk_angle.append(round(math.degrees(abs(math.atan(m_gk_goalcenter))), 2))
            
        # Add values to lists
        ls_goal_angle.append(round(math.degrees(abs(math.atan(m_shot_goalcenter))), 2))
        ls_distance_shot_goalcenter.append(round(math.dist([x_shot, y_shot], [120, 40]), 2))
        ls_distance_shot_goalline.append(120 - x_shot)
        ls_angular_deviation.append(round(math.degrees(abs(math.atan(m_shot_gk) - math.atan(m_bisector))), 2))
        # Calculate distance from shot position to goal
        x_goal = x_MH
        if y_shot > y_LH:
            y_goal = y_LH
        elif y_shot < y_RH:
            y_goal = y_RH
        # Add distance_shot_goal value to list    
        if y_goal > y_LH or y_goal < y_RH:
            ls_distance_shot_goal.append(round(math.dist([x_shot, y_shot], [x_goal, y_goal]), 2))
        else:
            ls_distance_shot_goal.append(x_goal - x_shot)
        # Add bool whether shooting cone includes no gk
        point = Point(x_gk, y_gk)
        polygon = Polygon([(x_shot, y_shot), (x_RH, y_RH), (x_LH, y_LH)])
        if polygon.contains(point) == True:
            ls_shooting_cone_without_gk.append(False)
        else:
            ls_shooting_cone_without_gk.append(True)
        
    # Add lists to dataframe
    df['goal_angle'] = ls_goal_angle
    df['gk_angle'] = ls_gk_angle
    df['distance_shot_goal'] = ls_distance_shot_goal
    df['distance_shot_goalline'] = ls_distance_shot_goalline
    df['distance_shot_goalcenter'] = ls_distance_shot_goalcenter
    df['angular_deviation'] = ls_angular_deviation
    df['shooting_cone_without_gk'] = ls_shooting_cone_without_gk
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_reduce = alt(df_all)
df_reduce.head(1)
# Out:
#   outcome  statsbomb_xg possession_team shot_body_part shot_technique  \
# 0   Saved        0.0593         Denmark     Right Foot         Normal
#
#        goalkeeper  goalkeeper_id  x_shot  y_shot   x_gk  y_gk  \
# 0  Lukáš Hrádecký           8667    97.7    33.3  119.2  38.1
#
#                                     player_locations polygon_players  \
# 0  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#    polygon_players_count  shooting_angle  bisector_slope  x_gk_bisector  \
# 0                      0         18.7291          0.2918         115.86
#
#    y_gk_bisector  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  x_gk_line  \
# 0           38.6    117.29     38.75    117.97     39.39        118
#
#    y_gk_line  x_gk_arc  y_gk_arc  goal_angle  gk_angle  distance_shot_goal  \
# 0       39.4    116.17     38.85       16.72     67.17                22.3
#
#    distance_shot_goalline  distance_shot_goalcenter  angular_deviation  \
# ...

# %%
# Create previous dataframe with togkp from ml model
def gk_ml(df):
    
    # Create previous dataframe
    df = alt(df)
    # Mirror shots
    df = mirror_shots(df)
    # Create empty lists
    ls_y_shot = []
    ls_y_gk = []
    ls_x_gk_ml = []
    ls_y_gk_ml = []
    
    # Define features
    X_train = df[['x_gk_avg', 'y_gk_avg', 'shooting_angle', 'bisector_slope', 'goal_angle', 'distance_shot_goalcenter', 'distance_shot_goalline']]
    # Define target
    y_train = df[['x_gk', 'y_gk']]
    # Define model
    model = LinearRegression()
    # Fit model
    model.fit(X_train, y_train)
    # Apply model
    y_pred = model.predict(X_train)
    
    # Iterate over all rows in array
    for row in range(0, len(y_pred)):
        # Unmirror shot and gk position
        if df.at[row, 'mirror'] == True:
            # Add values to lists
            ls_y_shot.append(80 - df.iloc[row]['y_shot'])
            ls_y_gk.append(80 - df.iloc[row]['y_gk'])
            ls_y_gk_ml.append(round(80 - y_pred[row][1], 2))
        else:
            # Add values to lists
            ls_y_shot.append(df.iloc[row]['y_shot'])
            ls_y_gk.append(df.iloc[row]['y_gk'])
            ls_y_gk_ml.append(round(y_pred[row][1], 2))
        # Add x value to list (doesn't need to be unmirrored)
        ls_x_gk_ml.append(round(y_pred[row][0], 2))
        
    # Add lists to dataframes
    df['y_shot'] = ls_y_shot
    df['y_gk'] = ls_y_gk
    df['x_gk_ml'] = ls_x_gk_ml
    df['y_gk_ml'] = ls_y_gk_ml
    # Delete mirror column
    del df['mirror']
    
    # Return dataframe (exclude 'shot_body_part', 'shot_technique')
    return df[['outcome', 'statsbomb_xg', 'possession_team', 'goalkeeper', 'goalkeeper_id', 'x_shot', 'y_shot', 'x_gk', 'y_gk', 'x_gk_avg', 'y_gk_avg', 'x_gk_geo', 'y_gk_geo', 'x_gk_line', 'y_gk_line', 'x_gk_arc', 'y_gk_arc', 'x_gk_bisector', 'y_gk_bisector', 'x_gk_ml', 'y_gk_ml', 'player_locations', 'polygon_players', 'polygon_players_count', 'shooting_cone_without_gk', 'shooting_angle', 'goal_angle', 'gk_angle', 'bisector_slope', 'distance_shot_goal', 'distance_shot_goalline', 'distance_shot_goalcenter', 'angular_deviation']]

# Apply method and display dataframe
df_gk_ml = gk_ml(df_all)
df_gk_ml.head(1)
# Out:
#   outcome  statsbomb_xg possession_team      goalkeeper  goalkeeper_id  \
# 0   Saved        0.0593         Denmark  Lukáš Hrádecký           8667
#
#    x_shot  y_shot   x_gk  y_gk  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  \
# 0    97.7    33.3  119.2  38.1    117.29     38.75    117.97     39.39
#
#    x_gk_line  y_gk_line  x_gk_arc  y_gk_arc  x_gk_bisector  y_gk_bisector  \
# 0        118       39.4    116.17     38.85         115.86           38.6
#
#    x_gk_ml  y_gk_ml                                   player_locations  \
# 0   117.07    38.88  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#   polygon_players  polygon_players_count  shooting_cone_without_gk  \
# 0                                      0                     False
#
#    shooting_angle  goal_angle  gk_angle  bisector_slope  distance_shot_goal  \
# 0         18.7291       16.72     67.17          0.2918                22.3
#
#    distance_shot_goalline  distance_shot_goalcenter  angular_deviation
# ...

# %%
# Create final dataframe
def final(df):
    
    # Create previous dataframe
    df = gk_ml(df)
    # Add values to dataframe
    df = distance_reaction(df)
    df = max_open_goal(df)
    
    # Add values for each togkp model to dataframe
    for gk_name in LS_TOGKP_MODEL_NAMES:
        df_reduce = distance_gk_gk_alt(df, gk_name)
    for gk_name in LS_TOGKP_MODEL_NAMES:
        df_reduce = distance_gk_avg_gk_alt(df, gk_name)
    for gk_name in LS_TOGKP_MODEL_NAMES:
        df_reduce = distance_gk_goalline(df, gk_name)
    for gk_name in LS_TOGKP_MODEL_NAMES:
        df_reduce = distance_gk_bisector(df, gk_name) 
    for gk_name in LS_TOGKP_MODEL_NAMES:
        df_reduce = ratio_shotgk_gkbisector(df, gk_name)
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_final = final(df_all)
df_final.head(1)
# Out:
#   outcome  statsbomb_xg possession_team      goalkeeper  goalkeeper_id  \
# 0   Saved        0.0593         Denmark  Lukáš Hrádecký           8667
#
#    x_shot  y_shot   x_gk  y_gk  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  \
# 0    97.7    33.3  119.2  38.1    117.29     38.75    117.97     39.39
#
#    x_gk_line  y_gk_line  x_gk_arc  y_gk_arc  x_gk_bisector  y_gk_bisector  \
# 0        118       39.4    116.17     38.85         115.86           38.6
#
#    x_gk_ml  y_gk_ml                                   player_locations  \
# 0   117.07    38.88  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#   polygon_players  polygon_players_count  shooting_cone_without_gk  \
# 0                                      0                     False
#
#    shooting_angle  goal_angle  gk_angle  bisector_slope  distance_shot_goal  \
# 0         18.7291       16.72     67.17          0.2918                22.3
#
#    distance_shot_goalline  distance_shot_goalcenter  angular_deviation  \
# ...

# %%
# Filter dataframe for 1v1 situations
def filter_1v1(df):
    
    # Copy dataframe and exclude non 1v1 situations
    df = df.where(df['polygon_players_count'] == 0).dropna().reset_index(drop = True)
    
    # Return dataframe
    return df

# Apply method and display dataframe
df_1v1 = filter_1v1(df_final)
df_1v1.head(1)
# Out:
#   outcome  statsbomb_xg possession_team      goalkeeper  goalkeeper_id  \
# 0   Saved        0.0593         Denmark  Lukáš Hrádecký         8667.0
#
#    x_shot  y_shot   x_gk  y_gk  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  \
# 0    97.7    33.3  119.2  38.1    117.29     38.75    117.97     39.39
#
#    x_gk_line  y_gk_line  x_gk_arc  y_gk_arc  x_gk_bisector  y_gk_bisector  \
# 0      118.0       39.4    116.17     38.85         115.86           38.6
#
#    x_gk_ml  y_gk_ml                                   player_locations  \
# 0   117.07    38.88  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#   polygon_players  polygon_players_count shooting_cone_without_gk  \
# 0                                    0.0                    False
#
#    shooting_angle  goal_angle  gk_angle  bisector_slope  distance_shot_goal  \
# 0         18.7291       16.72     67.17          0.2918                22.3
#
#    distance_shot_goalline  distance_shot_goalcenter  angular_deviation  \
# ...

# %% [markdown]
# ### Other Methods

# %%
# Plot vertical pitch
def vertical_pitch():
    
    # Define pitch arguments
    pitch = VerticalPitch(
        pitch_type='statsbomb', # Define data provider
        pitch_color='#D3D3D3',  # Define pitch color
        line_color='white',     # Define line color
        goal_type='box',        # Define goal type
        linewidth=2.5,          # Define linewidth
        half=False,             # Show half pitch
        axis=True,              # Show axis
        label=False,            # Show labels
        tick=False              # Show ticks
    )
    
    # Specify figure size (width, height) and draw figure
    fig, ax = pitch.draw(figsize=(20, 10))
    
    # Scale plot
    plt.axis('scaled')
    plt.xlim([13, 67])
    plt.ylim([-5, 25])

# %%
# Plot one shot
def plot_one_shot(df, row):
    
    # Apply function
    vertical_pitch()
    
    # Plot shot position transformed from horizontal to vertical pitch
    x_shot = df.at[row, 'y_shot']
    y_shot = 120 - df.at[row, 'x_shot']
    plt.scatter(x_shot, y_shot, color='red', alpha=0.8)
    # Plot gk position transformed from horizontal to vertical pitch
    x_gk = df.at[row, 'y_gk']
    y_gk = 120 - df.at[row, 'x_gk']
    # Change gk position color for goals
    if df.at[row, 'outcome'] == 'Goal':
        color = 'orange'
    else:
        color = 'blue'
    plt.scatter(x_gk, y_gk, color=color, alpha=0.8)
    
    # Create labels for legend
    plt.scatter(1000, 1000, color='red', alpha=0.8, label='Shot Position')
    plt.scatter(1000, 1000, color='orange', alpha=0.8, label='Goalkeeper Position (Goal)')
    plt.scatter(1000, 1000, color='blue', alpha=0.8, label='Goalkeeper Position (No-Goal)')
    
    # Plot line between shot position and left goalpost
    x_values = [x_shot, x_LV]
    y_values = [y_shot, y_LV]
    plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
    # Plot line between shot position and right goalpost
    x_values = [x_shot, x_RV]
    y_values = [y_shot, y_RV]
    plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')
    
    # Calculate linear equation of bisector
    m_bisector = -(1/df.at[row, 'bisector_slope'])
    q_bisector = y_shot - m_bisector*x_shot
    # Plot bisector
    x = np.linspace(-5, 100, 100)
    y = m_bisector*x + q_bisector
    plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Bisector')

    # Plot legend
    plt.legend(loc='upper left', prop={'size': 20})
    # Scale plot
    plt.axis('scaled')
    plt.xlim([13, 67])
    if y_shot > 20:
        plt.ylim([-5, y_shot+5])
    else:
        plt.ylim([-5, 25])
    # Show plot
    plt.show()

# %%
# Plot all shots
def plot_all_shots(df):
    
    # Apply function
    vertical_pitch()
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Plot shot position transformed from horizontal to vertical pitch
        x_shot = df.at[row, 'y_shot']
        y_shot = 120 - df.at[row, 'x_shot']
        # Change shot position color for goals
        color = 'blue'
        if df.at[row, 'outcome'] == 'Goal':
            color = 'red'
        plt.scatter(x_shot, y_shot, color=color, alpha=0.8)

    # Create labels for legend
    plt.scatter(1000, 1000, color='red', alpha=0.8, label='Shot Position (Goal)')
    plt.scatter(1000, 1000, color='blue', alpha=0.8, label='Shot Position (No-Goal)')

    # Plot legend
    plt.legend(loc='upper left', prop={'size': 20})
    # Scale plot
    plt.axis('scaled')
    plt.xlim([-5, 85])
    plt.ylim([-5, 65])
    # Show plot
    plt.show()

# %%
# Plot all gk positions
def plot_all_gks(df, gk_name):
    
    # Apply function
    vertical_pitch()
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        
        # Plot gk position transformed from horizontal to vertical pitch
        x_gk = df.at[row, 'y_' + gk_name]
        y_gk = 120 - df.at[row, 'x_' + gk_name]
        # Change gk position color for goals
        color = 'blue'
        if df.at[row, 'outcome'] == 'Goal':
            color = 'red'
        plt.scatter(x_gk, y_gk, color=color, alpha=0.8)

    # Create labels for legend
    plt.scatter(1000, 1000, color='red', alpha=0.8, label='Goalkeeper Position (Goal)')
    plt.scatter(1000, 1000, color='blue', alpha=0.8, label='Goalkeeper Position (No-Goal)')

    # Plot legend
    plt.legend(loc='upper left', prop={'size': 20})
    # Show plot
    plt.show()

# %%
# Plot coordinate system
def coordinates(x, y):
    # Get inliine charts
    # %matplotlib inline
    # Define x range, y range, and tick interval for both axes
    xmin, xmax, ymin, ymax = -x, x, -y, y
    ticks_frequency = 1
    # Create figure and axes object
    fig, ax = plt.subplots(figsize=(10, 10))
    # Set face color
    fig.patch.set_facecolor('#ffffff')
    # Apply ranges to axes
    ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')
    # Set both axes to zero position
    ax.spines['bottom'].set_position('zero')
    ax.spines['left'].set_position('zero')
    # Hide the top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    # Set x label, y label, and add an origin label
    ax.set_xlabel('$x$', size=14, labelpad=-24, x=1.02)
    ax.set_ylabel('$y$', size=14, labelpad=-21, y=1.02, rotation=0)
    plt.text(0.49, 0.49, r'$O$', ha='right', va='top',
        transform=ax.transAxes,
             horizontalalignment='center', fontsize=14)
    # Create x tick, y tick, and apply them to both axes
    x_ticks = np.arange(xmin, xmax+1, ticks_frequency)
    y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
    ax.set_xticks(x_ticks[x_ticks != 0])
    ax.set_yticks(y_ticks[y_ticks != 0])
    ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
    ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
    # Add a grid
    ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2)

# %%
# Calculate deviations from gk position to alternative gk position
def xy_deviation(df, gk_alt):
    
    # Initialize variables
    x_tot = 0
    y_tot = 0
    x_tot_abs = 0
    y_tot_abs = 0

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):

        # Display gk position relative to centered togkp
        x = df_1v1.at[row, 'x_gk'] - df_1v1.at[row, 'x_' + gk_alt]
        y = df_1v1.at[row, 'y_gk'] - df_1v1.at[row, 'y_' + gk_alt]
        # Calculate total deviation
        x_tot = x_tot + x
        y_tot = y_tot + y
        # Calculate absolute total deviation
        x_tot_abs = x_tot_abs + abs(x)
        y_tot_abs = y_tot_abs + abs(y)

    # Calculate average deviation
    x_dev = round(x_tot / len(df), 2)
    y_dev = round(y_tot / len(df), 2)
    x_dev_abs = round(x_tot_abs / len(df), 2)
    y_dev_abs = round(y_tot_abs / len(df), 2)

    # Display results
    print('Deviation from gk position to', gk_alt)
    print('Deviation in x direction:', x_dev)
    print('Deviation in y direction:', y_dev)
    print('Absolute deviation in x direction:', x_dev_abs)
    print('Absolute deviation in y direction:', y_dev_abs)

# %%
# Plot one column on x and y axis each
def plot_xy(df, x_axis, y_axis):
    
    # Iterate over all rows in dataframe
    for row in range(0, len(df)):
        # Define x and y axis
        x = df.at[row, x_axis]
        y = df.at[row, y_axis]
        # Color for every outcome besides goals and saves
        color = 'orange'
        # Color for goals
        if df.at[row, 'outcome'] == 'Goal':
            color = 'red'
        # Color for saves
        if df.at[row, 'outcome'] == 'Saved':
            color = 'green'
        # Plot point
        plt.scatter(x, y, color=color)

        # Add axis label
        plt.xlabel(x_axis)
        plt.ylabel(y_axis)

    # Display plot
    plt.show()

# %%
# Plot any gk position relative to centered alternative gk position
def plot_deviation(df, gk_centered, gk_alt):
    
    # Create coordinate system
    coordinates(17, 17)

    # Iterate over all rows in dataframe
    for row in range(0, len(df)):

        # Save alternative gk position relative to centered gk position
        y = -(df.at[row, 'x_' + gk_centered] - df.at[row, 'x_' + gk_alt])
        x = -(df.at[row, 'y_' + gk_centered] - df.at[row, 'y_' + gk_alt])
        # Color for every outcome besides goals and saves
        color = 'orange'
        # Color for goals
        if df.at[row, 'outcome'] == 'Goal':
            color = 'red'
        # Color for saves
        if df.at[row, 'outcome'] == 'Saved':
            color = 'green'
        # Plot point
        plt.scatter(x, y, color=color)

# %% [markdown]
# ### Data

# %%
# Display final dataframe
df_final = final(df_all)
print('Number of rows:', len(df_final))
df_final.head(1)
# Out:
# Number of rows: 1174
#   outcome  statsbomb_xg possession_team      goalkeeper  goalkeeper_id  \
# 0   Saved        0.0593         Denmark  Lukáš Hrádecký           8667
#
#    x_shot  y_shot   x_gk  y_gk  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  \
# 0    97.7    33.3  119.2  38.1    117.29     38.75    117.97     39.39
#
#    x_gk_line  y_gk_line  x_gk_arc  y_gk_arc  x_gk_bisector  y_gk_bisector  \
# 0        118       39.4    116.17     38.85         115.86           38.6
#
#    x_gk_ml  y_gk_ml                                   player_locations  \
# 0   117.07    38.88  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#   polygon_players  polygon_players_count  shooting_cone_without_gk  \
# 0                                      0                     False
#
#    shooting_angle  goal_angle  gk_angle  bisector_slope  distance_shot_goal  \
# 0         18.7291       16.72     67.17          0.2918                22.3
#
# ...

# %%
# Display 1v1 dataframe
df_1v1 = filter_1v1(df_final)
print('Number of rows:', len(df_1v1))
df_1v1.head(1)
# Out:
# Number of rows: 562
#   outcome  statsbomb_xg possession_team      goalkeeper  goalkeeper_id  \
# 0   Saved        0.0593         Denmark  Lukáš Hrádecký         8667.0
#
#    x_shot  y_shot   x_gk  y_gk  x_gk_avg  y_gk_avg  x_gk_geo  y_gk_geo  \
# 0    97.7    33.3  119.2  38.1    117.29     38.75    117.97     39.39
#
#    x_gk_line  y_gk_line  x_gk_arc  y_gk_arc  x_gk_bisector  y_gk_bisector  \
# 0      118.0       39.4    116.17     38.85         115.86           38.6
#
#    x_gk_ml  y_gk_ml                                   player_locations  \
# 0   117.07    38.88  [[86.7, 21.4], [91.1, 43.6], [102.6, 33.2], [9...
#
#   polygon_players  polygon_players_count shooting_cone_without_gk  \
# 0                                    0.0                    False
#
#    shooting_angle  goal_angle  gk_angle  bisector_slope  distance_shot_goal  \
# 0         18.7291       16.72     67.17          0.2918                22.3
#
# ...

# %% [markdown]
# ### Plots Shot and Goalkeeper Positions

# %%
# Plot one shot
plot_one_shot(df_1v1, 0)

# %%
# Plot all shots
plot_all_shots(df_final)

# %%
# Plot all 1v1 shots
plot_all_shots(df_1v1)

# %%
# Plot all gk positions
plot_all_gks(df_1v1, 'gk_bisector')

# %% [markdown]
# ### Plot Relations

# %%
df_1v1.head(1)

# %%
plot_xy(df_1v1, 'shooting_angle', 'distance_shot_goalline')

# %%
plot_xy(df_1v1, 'distance_shot_goalline', 'distance_gk_goalline')

# %%
plot_xy(df_1v1, 'goal_angle', 'gk_angle')

# %%
plot_xy(df_1v1, 'statsbomb_xg', 'distance_gk_bisector')

# %%
plot_xy(df_1v1, 'distance_gk_bisector', 'distance_gk_goalline')

# %%
# Apply method for all gks and gk_avg     
plot_deviation(df_1v1, 'gk_avg', 'gk')

# %%
# Apply method for all gks and gk_bisector    
plot_deviation(df_1v1, 'gk', 'gk_bisector')

# %% [markdown]
# ### Deviations (numeric)

# %%
# Calculate mean value of column
def mean_value(df, col):
    print('Mean ' + col, round(df[col].mean(), 2))

# %%
# Calculate mean value of column for different outcomes
def mean_value_outcomes(df, col):
    
    # Print gk_name
    print(col)
    
    # Mean value for saves
    df_saved = df.where(df['outcome'] == 'Saved').dropna().reset_index(drop = True)
    print('Mean value for saves:', round(df_saved[col].mean(), 2))
    
    # Mean value for nogoals
    df_nogoal = df.where(df['outcome'] != 'Goal').dropna().reset_index(drop = True)
    print('Mean value for no-goals:', round(df_nogoal[col].mean(), 2))

    # Mean value for goals
    df_goal = df.where(df['outcome'] == 'Goal').dropna().reset_index(drop = True)
    print('Mean value goals:', round(df_goal[col].mean(), 2))
    print()

# %%
# Define lists of similar columns
ls_distance_gk_gk_alt = ['distance_gk_gk', 'distance_gk_gk_avg', 'distance_gk_gk_geo', 'distance_gk_gk_line', 'distance_gk_gk_arc', 'distance_gk_gk_bisector', 'distance_gk_gk_ml']
ls_distance_gk_avg_gk_alt = ['distance_gk_avg_gk', 'distance_gk_avg_gk_avg', 'distance_gk_avg_gk_geo', 'distance_gk_avg_gk_line', 'distance_gk_avg_gk_arc', 'distance_gk_avg_gk_bisector', 'distance_gk_avg_gk_ml']
ls_distance_gk_alt_bisector = ['distance_gk_bisector', 'distance_gk_avg_bisector', 'distance_gk_geo_bisector', 'distance_gk_line_bisector', 'distance_gk_arc_bisector', 'distance_gk_bisector_bisector', 'distance_gk_ml_bisector']
ls_x_togkp = ['x_gk', 'x_gk_avg', 'x_gk_geo', 'x_gk_line', 'x_gk_arc', 'x_gk_bisector', 'x_gk_ml']
ls_y_togkp = ['y_gk', 'y_gk_avg', 'y_gk_geo', 'y_gk_line', 'y_gk_arc', 'y_gk_bisector', 'y_gk_ml']

# %%
# Apply method for each column in list
for col_name in ls_distance_gk_avg:
    mean_value(df_1v1, col_name)

# %%
# Apply method for each column in list
for col_name in ls_y_togkp:
    mean_value_outcomes(df_1v1, col_name)

# %%
# Separately check average deviations from gk_alt in x and y direction
xy_deviation(df_1v1, 'gk_bisector')

# %% [markdown]
# ### Heatmaps

# %%
# Create empty dataframe and lists 
df = df_1v1.where(df_1v1['distance_shot_goalline'] < 20).dropna().reset_index(drop=True)
ls_x = []
ls_y = []

# Iterate over all rows in dataframe
for row in range(0, len(df)):
    # Add values to lists
    ls_x.append(df.at[row, 'y_gk'])
    ls_y.append(120 - df.at[row, 'x_gk'])

# Transform lists to arrays
ar_x = np.asarray(ls_x)
ar_y = np.asarray(ls_y)

# Rename arrays
x = ar_x
y = ar_y

# %%
# Create heatmap
heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

# Show plot
plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()

# %%
# Define method
def myplot(x, y, s, bins=1000):
    # Method
    heatmap, xedges, yedges = np.histogram2d(x, y, bins=bins)
    heatmap = gaussian_filter(heatmap, sigma=s)
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    # Return
    return heatmap.T, extent

fig, axs = plt.subplots(2, 2)
sigmas = [0, 16, 32, 64]

for ax, s in zip(axs.flatten(), sigmas):
    if s == 0:
        ax.plot(x, y, 'k.', markersize=5)
        ax.set_title('Scatter plot')
    else:
        img, extent = myplot(x, y, s)
        ax.imshow(img, extent=extent, origin='lower', cmap=cm.jet)
        ax.set_title('Smoothing with  $\sigma$ = %d' % s)
        
# Show plot
plt.show()

# %%
# Create heatmap
sns.jointplot(x=x, y=y, kind='hex')
# Show plot
plt.show()

# %% [markdown]
# ### Evaluate Statsbomb xG Performance

# %%
# Copy dataframe
df = df_1v1.copy()
# Create empty lists
ls_outcome_bin = []
ls_xg_bin = []

# Encode outcome to binary
for row in range(0, len(df)):
    if df.at[row, 'outcome'] == 'Goal':
        ls_outcome_bin.append(int(1))
    else:
        ls_outcome_bin.append(int(0))

# Encode xg to binary        
for row in range(0, len(df)):
    if df.at[row, 'statsbomb_xg'] >= 0.5:
        ls_xg_bin.append(int(1))
    else:
        ls_xg_bin.append(int(0))

# Add lists do dataframe
df['outcome_bin'] = ls_outcome_bin
df['statsbomb_xg_bin'] = ls_xg_bin

# Save dataframe
df = df[['outcome', 'outcome_bin', 'statsbomb_xg', 'statsbomb_xg_bin']]

# Initialize variables
tn = 0
tp = 0
fn = 0
fp = 0

# Update variables
for row in range(0, len(df)):
    if df.at[row, 'outcome_bin'] == 0 and df.at[row, 'statsbomb_xg_bin'] == 0:
        tn = tn + 1
    elif df.at[row, 'outcome_bin'] == 1 and df.at[row, 'statsbomb_xg_bin'] == 1:
        tp = tp + 1
    elif df.at[row, 'outcome_bin'] == 1 and df.at[row, 'statsbomb_xg_bin'] == 0:
        fn = fn + 1
    elif df.at[row, 'outcome_bin'] == 0 and df.at[row, 'statsbomb_xg_bin'] == 1:
        fp = fp + 1

# Calculate metrics
accuracy = round((tp + tn)/(tp + tn + fn + fp), 2)
precision = round(tp/(tp + fp), 2)
recall = round(tp/(tp + fn), 2)
f1 = round(2*precision*recall/(precision + recall), 2)

# Print metrics
print('Accuracy:', accuracy)
print()
print('Precision:', precision)
print()
print('Recall:', recall)
print()
print('F1:', f1)

# %% [markdown]
# ### ML-Algorithm to predict xG

# %%
def one_hot_encode(df, col):

    # Define encoder
    encoder = OneHotEncoder(dtype = 'int', handle_unknown = 'ignore')
    # Encode column
    df_encoder = pd.DataFrame(encoder.fit_transform(df[[col]]).toarray())
    
    # Create list with categorical values
    ls_cat_vals = sorted(df[col].unique().tolist())
    # Rename columns
    df_encoder.columns = ls_cat_vals
    
    # Merge encoded columns with original dataframe
    df = df.join(df_encoder)
    # Delete shot location column
    del df[col]

    # Return dataframe
    return df

# %%
# Initialize settings
plt.rc('font', size=14)
sns.set(style='white')
sns.set(style='whitegrid', color_codes=True)

# Initialize 1v1 dataframe
df = df_1v1.copy()

# Select all numeric/transformed features 
df = df[['outcome', 'statsbomb_xg', 'x_shot', 'y_shot', 'x_gk', 'y_gk', 'x_gk_avg', 'y_gk_avg', 'x_gk_geo', 'y_gk_geo', 'x_gk_line', 'y_gk_line', 'x_gk_arc', 'y_gk_arc', 'x_gk_bisector', 'y_gk_bisector', 'x_gk_ml', 'y_gk_ml', 'polygon_players_count', 'shooting_angle', 'bisector_slope', 'goal_angle', 'gk_angle', 'distance_shot_goalcenter', 'distance_shot_goalline', 'distance_gk_goalline', 'angular_deviation']]

# Select reduced features
# df = df[['outcome', 'shooting_angle', 'goal_angle', 'distance_shot_goalcenter', 'distance_gk_bisector', 'angular_deviation', 'ratio_shotgk_gkbisector']]

# Select reduced features without bisector features
# df = df[['outcome', 'shooting_angle', 'goal_angle', 'distance_shot_goalcenter']]

# Select coordinate features
# df = df[['outcome', 'x_shot', 'y_shot', 'x_gk', 'y_gk', 'x_gk_bisector', 'y_gk_bisector']]

# Select coordinate features without bisector features
# df = df[['outcome', 'x_shot', 'y_shot', 'x_gk', 'y_gk']]

# Select experimental features
# df = df[['outcome', 'distance_gk_bisector', 'angular_deviation', 'ratio_shotgk_gkbisector']]

# Create empty lists
ls_outcome_bin = []

# Encode outcome to binary
for row in range(0, len(df)):
    if df.at[row, 'outcome'] == 'Goal':
        ls_outcome_bin.append(int(1))
    else:
        ls_outcome_bin.append(int(0))

# Add lists do dataframe
df['outcome'] = ls_outcome_bin

# Display dataframe
df.head(1)

# %%
# Import package
from sklearn.metrics import confusion_matrix

# Initialize feature vector and target
X = df.loc[:, df.columns != 'outcome']
y = df.loc[:, df.columns == 'outcome']

# Implement model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

# Save predictions
y_pred = logreg.predict(X_test)

# Calculate confusion matrix and values
confusion_matrix = confusion_matrix(y_test, y_pred)
TN, FP, FN, TP = confusion_matrix.ravel()
accuracy =  (TP+TN) /(TP+FP+TN+FN)

# Display results
print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)
print('')
print('Number of correct predictions:', confusion_matrix[0][0] + confusion_matrix[1][1])
print('Number of incorrect predictions:', confusion_matrix[0][1] + confusion_matrix[1][0])
print('')
print('Accuracy of the binary classification = {:0.3f}'.format(accuracy))
print('')
print(classification_report(y_test, y_pred))

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc='lower right')
plt.savefig('Log_ROC')
plt.show()

# %%
# Show class imbalance
count_no_goal = len(df[df['outcome']==0])
count_goal = len(df[df['outcome']==1])
pct_of_no_goal = count_no_goal/(count_no_goal+count_goal)
pct_of_goal = count_goal/(count_no_goal+count_goal)
print('percentage of no goal is', pct_of_no_goal*100)
print('percentage of goal', pct_of_goal*100)

# %% [markdown]
# ### xG
# - https://github.com/hadisotudeh/cfg-datascience-task/blob/main/CFG_Data_Scientist_Task_HadiSotudeh.ipynb

# %%
# General libraries
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import numpy as np
import itertools
import warnings
import math
import os

# Machine learning libraries
from sklearn.metrics import plot_roc_curve, roc_auc_score, brier_score_loss
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import joblib

# Model interpretation library
from sklearn.inspection import plot_partial_dependence

# %%
# Show plots inside the jupyter notebook
# %matplotlib inline

# Pandas settings to show more columns are rows in the jupyter notebook
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50000)

# Increase font size of the plots 
plt.rcParams.update({'font.size': 18})

# Don't show warnings
warnings.filterwarnings('ignore')

# Target variable to predict
dep_var = 'outcome'

# Hyper-paramter tuning variables
cv = 5
seed = 42
scoring = 'roc_auc'

# %%
# Create and filter dataframe
df = df_final.copy()
df = df[['polygon_players_count', 'distance_shot_goalcenter', 'shooting_angle', 'outcome']]

# Encode outcome to binary
for row in range(0, len(df)):
    if df.at[row, 'outcome'] == 'Goal':
        df.at[row, 'outcome'] = 1
    else:
        df.at[row, 'outcome'] = 0   

# From object to int
df['outcome'] = df['outcome'].astype('int')

# Define features
features = [x for x in df.columns if x not in ['position_x','position_y',dep_var]]

# Display dataframe
df.head()

# %%
# Selecting correspondnig columns for training and test stes
X = df[features].values
y = df[dep_var].values

# Spliting train and test sets. 80% for the training and 20% for the test set.
xs, valid_xs, y, valid_y = train_test_split(X, y, test_size=0.20, random_state=seed, shuffle=True)

# %%
def calc_auc_roc(y, prob_pred):
  return roc_auc_score(y, prob_pred)

# %%
## Hyperparameters

lr_hyperparameters = {
    'lr__C': [0.01, 0.1, 1.0, 10, 100]
}

rf_hyperparameters = {
    'rf__n_estimators': np.arange(20,100,10),
    'rf__max_features': np.arange(0.5,1.0,0.1),
    'rf__max_depth': np.arange(1,20,5)
}

xgb_hyperparameters = {
    'xgb__max_depth': np.arange(2,12,2),  # the maximum depth of each tree
    'xgb__learning_rate': [0.1,0.3],  # the training step for each iteration
    'xgb__n_estimators': np.arange(1,80,10)
}

lgbm_hyperparameters = {
    'lgbm__n_estimators': np.arange(10,140,20),
    'lgbm__min_data_in_leaf': np.arange(100,1000,100),
    'lgbm__max_depth': np.arange(2,10,2)
}

hyperparameters = {
    'lr': lr_hyperparameters,
    'rf': rf_hyperparameters,
    'lgbm': lgbm_hyperparameters,
    'xgb': xgb_hyperparameters
}

# Pipeline of ML classiferis' pipielines 
pipelines = {
    'bl': Pipeline([('bl', DummyClassifier(strategy='most_frequent'))]), # base line
    'lr': Pipeline([('lr',LogisticRegression(random_state=seed, n_jobs=-1, penalty='l2'))]),
    'rf': Pipeline([('rf', RandomForestClassifier(random_state=seed, n_jobs=-1, oob_score=True))]),
    'xgb': Pipeline([('xgb', XGBClassifier(random_state=seed, n_jobs=-1))]),
    'lgbm': Pipeline([('lgbm', LGBMClassifier(random_state=seed, n_jobs=-1))])
}

# %%
# Start the training process

results = []
model_names = {'bl':'Baseline', 'lr': 'Logistic Regression' , 'rf':'Random Forest', 
               'xgb': 'XGBoost', 'lgbm': 'Light Gradient Boosting'}

fig, ax =  plt.subplots(figsize=(8, 8))
ax.plot([0, 1], [0, 1], 'k:', label='Perfectly calibrated')

for key, pipeline in tqdm(pipelines.items()):
  if key == 'bl':
      model = pipeline
  else:
      model = GridSearchCV(pipeline, hyperparameters[key], cv=cv, scoring=scoring, n_jobs=-1)

  model.fit(xs,y)

  if hasattr(model,'best_estimator_'):
      best = model.best_estimator_.named_steps[key]
  else:
      best = model

  result = {}

  result['model'] = model_names[key]

  train_prob_pred = best.predict_proba(xs)[:,1]

  result['training (auc roc)'] = calc_auc_roc(y, train_prob_pred)
  
  validation_prob_pred = best.predict_proba(valid_xs)[:,1]

  result['validation (auc roc)']  = calc_auc_roc(valid_y, validation_prob_pred)


  fraction_of_positives, mean_predicted_value = calibration_curve(valid_y, validation_prob_pred, n_bins=10)

  result['Brier score'] = brier_score_loss(valid_y, validation_prob_pred)

  results.append(result)

  # Do not log calibration information for baseline fitter, as I already have done it.
  if key == 'bl':
    continue

  # Plot the calibration plot  
  ax.plot(mean_predicted_value, fraction_of_positives, 's-', label='%s' % (model_names[key], ))
    
  # Save the model
  joblib.dump(best, f'{model_names[key]}.joblib')

results_df = pd.DataFrame(results).round(3)
display(results_df)

ax.set_xlabel('Mean predicted value')
ax.set_ylabel('Fraction of positives')
ax.set_ylim([-0.05, 1.05])
ax.legend(loc='lower right')
ax.set_title('Calibration plot  (reliability curve)')

plt.tight_layout()
plt.savefig('calibartion_plot.png', bbox_inches='tight')
plt.show()

# %%
best_model_name = 'Logistic Regression'
selected_model = joblib.load(f'{best_model_name}.joblib')
print(f'selected model is {best_model_name}.\n')
print('Its parameters are:')
selected_model.get_params()

# %%
fig, ax =  plt.subplots(figsize=(7, 7))
ax.set_title('AUC ROC Curve of the Logistic Regression Model')
plot_roc_curve(selected_model, valid_xs, valid_y, ax=ax);

# %%
intercept = round(selected_model.intercept_[0],2)
print(f'The model intercept is {intercept}\n')

coefficients = [round(c,2) for c in selected_model.coef_[0]]

print('The model coefficients are:')
pd.DataFrame(coefficients, features, columns=['coef']).sort_values(by='coef', ascending=False)

# %%
explore_cols = ['polygon_players_count', 'distance_shot_goalcenter', 'shooting_angle']

valid_xs_df = pd.DataFrame(valid_xs, columns = features)

for index, col in enumerate(explore_cols):
    fig,ax = plt.subplots(figsize=(12, 4))
    plot_partial_dependence(selected_model, valid_xs_df, [col], grid_resolution=20, ax=ax);

# %%
paired_features = [
                  ('shooting_angle','distance_shot_goalcenter'),
                  ('shooting_angle','polygon_players_count'),
                  ('distance_shot_goalcenter','polygon_players_count'), 
                  ]

for index, pair in enumerate(paired_features):
  fig,ax = plt.subplots(figsize=(8, 8))
  plot_partial_dependence(selected_model, valid_xs_df, [pair], grid_resolution=20, ax=ax);

# %%
# Calculate xG value
def calc_xG(instance):
  '''Predict the goal-scoring probability of a shot by applying the trained model'''
  x = instance[features].values.reshape(1,-1)
  return round(selected_model.predict_proba(x)[:,1][0],2)

# Apply function
df['xG'] = df.apply(lambda instance: calc_xG(instance), axis=1)

# Display dataframe
df

# %%
# Binning xG

def calc_xg_quality(xg):
  if xg < 0.07:
    return 'poor'
  elif 0.07 <= xg < 0.15:
    return 'fair'
  elif 0.15 <= xg < 0.30:
    return 'good'
  elif 0.30 <= xg:
    return 'very good'

df['xG_quality'] = df['xG'].apply(lambda xg: calc_xg_quality(xg))
df

# %%
df['pred'] = 0

for row in range(0, len(df)):
    if df.at[row, 'xG'] >= 0.5:
        df.at[row, 'pred'] = 1
    else:
        df.at[row, 'pred'] = 0
df

# %%
df.sort_values(by=['xG'])

# %%
# Import package
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix and values
y_test = np.array(df['outcome'].to_list())
y_pred = np.array(df['pred'].to_list())

confusion_matrix = confusion_matrix(y_test, y_pred)
TN, FP, FN, TP = confusion_matrix.ravel()
accuracy =  (TP+TN) /(TP+FP+TN+FN)

# Display results
print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)
print('')
print('Number of correct predictions:', confusion_matrix[0][0] + confusion_matrix[1][1])
print('Number of incorrect predictions:', confusion_matrix[0][1] + confusion_matrix[1][0])
print('')
print('Accuracy of the binary classification = {:0.3f}'.format(accuracy))
print('')
print(classification_report(y_test, y_pred))

# %% [markdown]
# ### Find best ML-Algorithm to predict Goalkeeper Position

# %%
# Create dataframe
df_mirror_final = mirror_shots(df_final)
df_mirror_1v1 = mirror_shots(df_1v1)
# Lists with all dataframe names to test
ls_dataframe_names = [df_final, df_mirror_final, df_1v1, df_mirror_1v1]
ls_names = ['final', 'mirror_final', '1v1', 'mirror_1v1']
# Initialize counter
counter = 0

# Iterate over all dataframe names
for dataframe_name in ls_dataframe_names:
    # Define dataframe
    df = dataframe_name
    # Define features and targets
    # X = df[['x_shot', 'y_shot']]
    # X = df[['x_gk_avg', 'y_gk_avg']]
    X = df[['x_gk_avg', 'y_gk_avg', 'shooting_angle', 'bisector_slope', 'goal_angle', 'distance_shot_goalcenter', 'distance_shot_goalline']]
    y = df[['x_gk', 'y_gk']]
    # Define train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    # Total number of test rows
    n_test = len(y_test)
    
    print()
    print()
    

    # Iterate over all model names
    for model_name in LS_ML_MODEL_NAMES:    
        # Define model
        model = model_name
        # Fit model
        model.fit(X_train, y_train)
        # Test model
        y_pred = model.predict(X_test) 

        # Initialize variables
        x_ae = 0
        y_ae = 0
        d_ae = 0
        y_test_reset = y_test.reset_index()
        # Iterate over all test rows
        for row in range (0, n_test):
            x_ae = x_ae + abs(y_pred[row][0] - y_test_reset.at[row, 'x_gk'])
            y_ae = y_ae + abs(y_pred[row][1] - y_test_reset.at[row, 'y_gk'])
            d_ae = d_ae + round(math.dist([y_pred[row][0], y_pred[row][1]], [y_test_reset.at[row, 'x_gk'], y_test_reset.at[row, 'y_gk']]), 2)
        # Calculate mean absolute error
        x_mae = x_ae / n_test
        y_mae = y_ae / n_test
        d_mae = d_ae / n_test

        # Print results
        print('Dataframe:', ls_names[counter])
        print('ML model:', model_name)
        print('x_mae:', x_mae)
        print('y_mae:', y_mae)
        print('d_mae:', d_mae)
        print()
    
    # Update counter
    counter = counter + 1

# %%
for dataframe_name in [df_final, df_1v1]:
    # Define dataframe
    df = dataframe_name
    # Define features and targets
    X = df[['goal_angle']]
    y = df[['gk_angle']]
    # Define train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    # Total number of test rows
    n_test = len(y_test)
    
    print()
    print()

    # Iterate over all model names
    for model_name in LS_ML_MODEL_NAMES:    
        # Define model
        model = model_name
        # Fit model
        model.fit(X_train, y_train)
        # Test model
        y_pred = model.predict(X_test) 

        # Print results
        print(model_name)
        print(mean_absolute_error(y_test, y_pred))
        print()

# %%
# Define model
model = LinearRegression()
# Define evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# Evaluate model and collect scores
n_scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# Force scores to be positive
n_scores = abs(n_scores)
# Summarize performance
print(mean(n_scores))

# %%
# Define pipeline
my_pipeline = Pipeline(steps=[
    ('preprocessor', SimpleImputer()),
    ('model', RandomForestRegressor(n_estimators=50, random_state=0))
])

# %%
# Multiply by -1 since sklearn calculates 'negative' MAE
scores = -1 * cross_val_score(my_pipeline, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print('Average MAE score:', scores.mean())

# %%
# Define and check function
def get_score(n_estimators):
    my_pipeline = Pipeline(steps=[
        ('preprocessor', SimpleImputer()),
        ('model', RandomForestRegressor(n_estimators, random_state=0))
    ])
    scores = -1 * cross_val_score(my_pipeline, X, y,
                                  cv=3,
                                  scoring='neg_mean_absolute_error')
    return scores.mean()

# %% [markdown]
# ### Information used in Thesis

# %% [markdown]
# Display exemplary json file as dataframe:

# %%
# Create dataframe
df_test = pd.read_json(EVENTPATH)

# Display dataframe
df_test

# %% [markdown]
# Display column names:

# %%
# Display column names
df_test.columns.to_list()

# %% [markdown]
# Calculate total number of games and average number of events per game:

# %%
# Initialize variables
filecount = 0
eventcount = 0

# Iterate over all files in directory
for filename in os.listdir(DIRECTORY):

    # Save current filepath
    filepath = os.path.join(DIRECTORY, filename)
    # Check if current file has json ending
    if filename.split('.')[1] == 'json':

        # Create dataframe from current json file
        df_file = pd.read_json(filepath)
        # Update counters
        eventcount = eventcount + len(df_file)
        filecount = filecount + 1

# Calculate average number of events per game
avg_events = round(eventcount / filecount, 2)

# Display results
print('Total number of games:', filecount)
print('Average number of events per game:', avg_events)

# %% [markdown]
# Caclulate total number and percentage of games with one or zero goals difference:

# %%
# Create dataframe
df_matches = pd.read_json(MATCHPATH)

# Calculate goal difference
df_matches['goal_difference'] = abs(df_matches['home_score'] - df_matches['away_score'])

# Save goal difference
goal_difference = df_matches['goal_difference'].where(df_matches['goal_difference'] <= 1).dropna().count()

# Display results
print('Total number of games with one or zero goals difference:', goal_difference)
print('Percentage of games with one or zero goals difference:', round(100*goal_difference/filecount, 2), '%')

# %% [markdown]
# Calculate total number of shots:

# %%
df_all['shot'].dropna().count()

# %% [markdown]
# Calculate total number of deflections and set pieces:

# %%
# Define variable and dataframe
deflections = 0
set_pieces = 0
df_all_shots = df_all.dropna().reset_index(drop = True)

# Iterate over all rows in dataframe
for row in range(0, len(df_all_shots)):
    if 'deflected' in df_all_shots.iloc[row]['shot']:
        deflections = deflections + 1
    if df_all_shots.at[row, 'shot']['type']['name'] != 'Open Play':
        set_pieces = set_pieces + 1

# Display results
print('Total number of deflections:', deflections)
print('Total number of set pieces:', set_pieces)

# %% [markdown]
# Prove that there are no registered headers:

# %%
# Define variable and dataframe
headers = 0

# Iterate over all rows in dataframe
for row in range(0, len(df_shot)):
    if df_shot.iloc[0]['shot']['body_part']['name'] == 'Right Foot':
        headers = headers + 1

# Display results
print('Total number of headers:', headers)

# %% [markdown]
# Caclulate percentage of off target shots:

# %%
shots_off_target = df_final['outcome'].where((df_final['outcome'] == 'Off T') | (df_final['outcome'] == 'Blocked') | (df_final['outcome'] == 'Wayward') | (df_final['outcome'] == 'Saved Off Target') | (df_final['outcome'] == 'Post')).dropna().count()
shots_total = df_final['outcome'].count()

print('Percentage of off target shots:', round(100*shots_off_target/shots_total, 2), '%')

# %% [markdown]
# Reason for setting ratio_shooter_perp values to 4030 in case perp = 0:

# %%
# Display maximum value for ratio_shooter_perp
df_1v1.where(df_1v1['ratio_shotgk_gkbisector'] > 4030).dropna()

# %% [markdown]
# Check which goalkeeper reach value results in smallest distance between GKP and TOGKP:
# - Final goalkeeper reach: 3.5
# - Final mean distance: 1.7

# %%
# Initilaize variables
goalkeeper_reach = 1.8

while goalkeeper_reach < 3.8:
    df_experimental = reduce(df_all)
    print('dr:', goalkeeper_reach)
    print('d:', df_experimental['distance'].where(df_experimental['outcome'] == 'Saved').mean())
    goalkeeper_reach = goalkeeper_reach + 0.1

# %%
# Initilaize variables
goalkeeper_reach = 3.1
mean_distance = 100
count = 0

# Do as long as result does not get worse three times in a row
while count < 3:
    
    # Create dataframe with current dive radius
    df_experimental = reduce(df_all)
    
    # If mean distance is smaller update parameters and reset count to zero
    if df_experimental['distance'].mean() < mean_distance:
        mean_distance = df_experimental['distance'].mean()
        result = goalkeeper_reach
        count = 0
    # If mean distance is larger add one to count
    else:
        count = count + 1
    
    # Increase dive radius
    goalkeeper_reach = goalkeeper_reach + 0.1

# Print results
print('Final goalkeeper_reach:', result)
print('Final mean distance:', mean_distance)

# %% [markdown]
# ### Plots used in Thesis

# %% [markdown]
# Dive shadow:

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)')
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
plt.scatter(x_GKV, y_GKV, color='blue', alpha=0.8, label='Goalkeeper Position (G)')
plt.text(x_GKV+0.5, y_GKV, 'G', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot dive shadow
plt.gca().plot(x_GKV, y_GKV, 'o', ms=138, mec='none', mfc='blue', alpha=0.2, mew=0)
plt.scatter(1000, 1000, color='blue', alpha=0.2, label='Dive Shadow')

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_SV, x_LV]
y_values = [y_SV, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_SV, x_RV]
y_values = [y_SV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/dive_shadow.png')
plt.show()

# %% [markdown]
# Goalkeeper's reach:

# %%
# x_SV, y_SV = origin = shot coordinates
# x_LV, y_LV = point = left goalpost coordinates
# x_r, y_r = result = rotated point coordinates

# Calculate linear equation between shot position and left goalpost
m_lv = (y_LV - y_SV)/(x_LV - x_SV)
q_lv = y_SV - m_lv*x_SV
# Calculate linear equation between shot position and right goalpost
m_rv = (y_RV - y_SV)/(x_RV - x_SV)
q_rv = y_SV - m_rv*x_SV

# Calculate shooting angle
shooting_angle = math.degrees(abs(math.atan(m_lv) - math.atan(m_rv)))
# Calculate half shooting angle
ang = math.radians(shooting_angle)/2

# Rotate point counterclockwise by defined angle in radians around defined origin
x_rotated = x_SV + math.cos(ang)*(x_LV-x_SV) - math.sin(ang)*(y_LV-y_SV)
y_rotated = y_SV + math.sin(ang)*(x_LV-x_SV) + math.cos(ang)*(y_LV-y_SV)

# Calculate linear equation of bisector
m_bisector = (y_rotated-y_SV)/(x_rotated-x_SV)
q_bisector = y_SV - m_bisector*x_SV
# Calculate linear equation perpendicular to bisector
m_perpendicular = -(1/m_bisector)
q_perpendicular = y_GKV - m_perpendicular*x_GKV

# Calculate left intersection
y_l = (q_lv - q_perpendicular*m_lv/m_perpendicular)/(1 - (m_lv/m_perpendicular))
x_l = (y_l - q_perpendicular)/m_perpendicular
# Calculate right intersection
y_r = (q_rv - q_perpendicular*m_rv/m_perpendicular)/(1 - (m_rv/m_perpendicular))
x_r = (y_r - q_perpendicular)/m_perpendicular

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)', zorder=2)
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
plt.scatter(x_GKV, y_GKV, color='blue', alpha=0.8, label='Goalkeeper Position (G)')
plt.text(x_GKV+0.5, y_GKV, 'G', fontsize=20)
# Plot left intersection
plt.scatter(x_l, y_l, color='blue', alpha=0.8)
plt.text(x_l, y_l, '  L\'', fontsize=20)
# Plot right intersection
plt.scatter(x_r, y_r, color='blue', alpha=0.8)
plt.text(x_r, y_r, '  R\'', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot gk reach
x = np.linspace(39, 44.5, 100)
y = m_perpendicular*x + q_perpendicular
plt.plot(x, y, color='blue', alpha=0.4, label= 'Goalkeeper\'s Reach (L\'R\')')

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_SV, x_LV]
y_values = [y_SV, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_SV, x_RV]
y_values = [y_SV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')
# Plot bisector
x = np.linspace(-5, 100, 100)
y = m_bisector*x + q_bisector
plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Bisector', zorder=1)

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/gk_reach.png')
plt.show()

# %% [markdown]
# Shooting angle:

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)')
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
plt.scatter(x_GKV, y_GKV, color='blue', alpha=0.8, label='Goalkeeper Position (G)')
plt.text(x_GKV+0.5, y_GKV, 'G', fontsize=20)
# Plot shooting angle
x = np.linspace(100, 100, 100)
y = m_bisector*x + q_bisector
plt.plot(x, y, color='black', alpha=0.4, label='Shooting Angle (\u03C6)')
plt.text(48.4, 17, '\u03C6', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_SV, x_LV]
y_values = [y_SV, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_SV, x_RV]
y_values = [y_SV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/shooting_angle.png')
plt.show()

# %% [markdown]
# Zones:

# %%
# Apply function
vertical_pitch()

# Plot zone 1
x, y = [40, 18, 18], [0, 13, 0]
plt.fill(x, y, color='green', alpha=0.2)
x, y = [40, 62, 62], [0, 13, 0]
plt.fill(x, y, color='green', alpha=0.2)
plt.scatter(1000, 1000, color='green', alpha=0.2, label='Zone 1')
# Plot zone 2
x, y = [40, 32, 18, 18], [0, 18, 18, 13]
plt.fill(x, y, color='orange', alpha=0.2)
x, y = [40, 48, 62, 62], [0, 18, 18, 13]
plt.fill(x, y, color='orange', alpha=0.2)
plt.scatter(1000, 1000, color='orange', alpha=0.2, label='Zone 2')
# Plot zone 3
x, y = [40, 32, 48], [0, 18, 18]
plt.fill(x, y, color='red', alpha=0.2)
plt.scatter(1000, 1000, color='red', alpha=0.2, label='Zone 3')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/zones_3.png')
plt.show()

# %% [markdown]
# Zone 1:

# %%
# Apply function
vertical_pitch()

# Plot zone 1
x, y = [40, 18, 18], [0, 13, 0]
plt.fill(x, y, color='green', alpha=0.2)
x, y = [40, 62, 62], [0, 13, 0]
plt.fill(x, y, color='green', alpha=0.2)
plt.scatter(1000, 1000, color='green', alpha=0.2, label='Zone 1')

# Plot shot position
x_shot = 56
y_shot = 5
plt.scatter(x_shot, y_shot, color='red', alpha=0.8, label='Shooting Position (S)', zorder=2)
plt.text(x_shot+0.5, y_shot-0.8, 'S', fontsize=20)
# Plot gk position
x_gk = 44.5
y_gk = 1.39
plt.scatter(x_gk, y_gk, color='blue', alpha=0.8, label='TOGKP (G)')
plt.text(x_gk+0.4, y_gk-0.6, 'G', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_shot, x_LV]
y_values = [y_shot, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_shot, x_RV]
y_values = [y_shot, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')
# Plot ballline
m_ballline = (y_shot - y_MV)/(x_shot - x_MV)
q_ballline = y_shot - m_ballline*x_shot
x = np.linspace(-5, 100, 100)
y = m_ballline*x + q_ballline
plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Ball Line', zorder=1)

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/zone_1.png')
plt.show()

# %% [markdown]
# Zone 2:

# %%
# Apply function
vertical_pitch()

# Plot zone 2
x, y = [40, 32, 18, 18], [0, 18, 18, 13]
plt.fill(x, y, color='orange', alpha=0.2)
x, y = [40, 48, 62, 62], [0, 18, 18, 13]
plt.fill(x, y, color='orange', alpha=0.2)
plt.scatter(1000, 1000, color='orange', alpha=0.2, label='Zone 2')

# Plot shot position
x_shot = 52
y_shot = 13
plt.scatter(x_shot, y_shot, color='red', alpha=0.8, label='Shooting Position (S)', zorder=2)
plt.text(x_shot+0.5, y_shot-0.8, 'S', fontsize=20)
# Plot gk position
x_gk = 43.2
y_gk = 3.5
plt.scatter(x_gk, y_gk, color='blue', alpha=0.8, label='TOGKP (G)')
plt.text(x_gk+0.4, y_gk-0.6, 'G', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_shot, x_LV]
y_values = [y_shot, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_shot, x_RV]
y_values = [y_shot, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')
# Plot ballline
m_ballline = (y_shot - y_MV)/(x_shot - x_MV)
q_ballline = y_shot - m_ballline*x_shot
x = np.linspace(-5, 100, 100)
y = m_ballline*x + q_ballline
plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Ball Line', zorder=1)

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/zone_2.png')
plt.show()

# %% [markdown]
# Zone 3:

# %%
# Apply function
vertical_pitch()

# Plot zone 3
x, y = [40, 32, 48], [0, 18, 18]
plt.fill(x, y, color='red', alpha=0.2)
plt.scatter(1000, 1000, color='red', alpha=0.2, label='Zone 3')

# Plot shot position
x_shot = 40
y_shot = 14
plt.scatter(x_shot, y_shot, color='red', alpha=0.8, label='Shooting Position (S)', zorder=2)
plt.text(x_shot+0.5, y_shot, 'S', fontsize=20)
# Plot gk position
x_gk = 40
y_gk = 4.5
plt.scatter(x_gk, y_gk, color='blue', alpha=0.8, label='TOGKP (G)')
plt.text(x_gk+0.5, y_gk, 'G', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_shot, x_LV]
y_values = [y_shot, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_shot, x_RV]
y_values = [y_shot, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')
# Plot ballline
# Plot line between shot position and right goalpost
x_values = [x_MV, x_MV]
y_values = [100, -100]
plt.plot(x_values, y_values, color='green', alpha=0.4, linestyle='dashed', label='Ball Line', zorder=1)

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/zone_3.png')
plt.show()

# %% [markdown]
# Geometric model:

# %%
# Apply function
vertical_pitch()

# Plot red zone
x, y = [18, 18, 0, 0, 18, 18, 32, 32, 48, 48, 62, 62, 80, 80, 62, 62], [120-60, 120-98.85, 120-98.85, 120-114, 120-114, 120-102, 120-102, 120-98.85, 120-98.85, 120-102, 120-102, 120-114, 120-114, 120-98.85, 120-98.85, 120-60]
plt.fill(x, y, color='red', alpha=0.2)
plt.scatter(1000, 1000, color='red', alpha=0.2, label='Red Zone')
# Plot orange zones
x, y = [62, 62, 80, 80], [120-114, 120-120, 120-120, 120-114]
plt.fill(x, y, color='orange', alpha=0.2)
x, y = [18, 18, 0, 0], [120-114, 120-120, 120-120, 120-114]
plt.fill(x, y, color='orange', alpha=0.2)
x, y = [62, 62, 80, 80], [120-60, 120-98.85, 120-98.85, 120-60]
plt.fill(x, y, color='orange', alpha=0.2)
x, y = [18, 18, 0, 0], [120-60, 120-98.85, 120-98.85, 120-60]
plt.fill(x, y, color='orange', alpha=0.2)
plt.scatter(1000, 1000, color='orange', alpha=0.2, label='Orange Zone')
# Plot blue zone
x, y = [36.774625, 39.085, 40.915, 43.225375], [120-98.85, 120-114, 120-114, 120-98.85]
plt.fill(x, y, color='blue', alpha=0.4)
plt.scatter(1000, 1000, color='blue', alpha=0.4, label='Blue Zone')
# Plot light blue zones
x, y = [18, 18, 36, 39.085, 36.774625, 32, 32], [120-102, 120-106.8, 120-117.6, 120-114, 120-98.85, 120-98.85, 120-102]
plt.fill(x, y, color='blue', alpha=0.2)
x, y = [43.225375, 40.915, 44, 62, 62, 48, 48], [120-98.85, 120-114, 120-117.6, 120-106.8, 120-102, 120-102, 120-98.85]
plt.fill(x, y, color='blue', alpha=0.2)
plt.scatter(1000, 1000, color='blue', alpha=0.2, label='Light Blue Zone')
# Plot yellow zones
x, y = [18, 18, 36, 36], [120-106.8, 120-120, 120-120, 120-117.6]
plt.fill(x, y, color='yellow', alpha=0.2)
x, y = [44, 44, 62, 62], [120-117.6, 120-120, 120-120, 120-106.8]
plt.fill(x, y, color='yellow', alpha=0.2)
plt.scatter(1000, 1000, color='yellow', alpha=0.2, label='Yellow Zone')

# Define orange point
x_orange = 40
y_orange = 2.4

# Plot left red line
x_values = [x_LV, x_orange]
y_values = [y_LV, y_orange]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Red Line', zorder = 1)
# Plot right red line
x_values = [x_RV, x_orange]
y_values = [y_RV, y_orange]
plt.plot(x_values, y_values, color='red', alpha=0.4, zorder = 1)

# Plot orange point
plt.scatter(x_orange, y_orange, color='orange', label='Orange Point', zorder = 2)
# Plot goalpoasts
plt.scatter(x_LV, y_LV, color='red', alpha=0.8, label='Left Goalpost (L)')
plt.text(x_LV-1.7, y_LV-2, 'L', fontsize=20)
# Plot goalpoasts
plt.scatter(x_RV, y_RV, color='red', alpha=0.8, label='Right Goalpost (R)')
plt.text(x_RV+0.5, y_RV-2, 'R', fontsize=20)

# Plot legend and scale plot
plt.legend(loc='upper left', prop={'size': 20})
plt.axis('scaled')
plt.xlim([-5, 85])
plt.ylim([-5, 65])
# Save and show plot
plt.savefig('images/zones_colors.png')
plt.show()

# %% [markdown]
# Alternative goalkeeper positions:

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)')
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
plt.scatter(x_GKV, y_GKV, color='blue', alpha=0.8, label='Goalkeeper Position')
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot alternative gk positions
plt.scatter(x_GKV, y_GKV+1, color='blue', alpha=0.4)
plt.scatter(x_GKV+0.7, y_GKV+0.7, color='blue', alpha=0.4)
plt.scatter(x_GKV+1, y_GKV, color='blue', alpha=0.4)
plt.scatter(x_GKV+0.7, y_GKV-0.7, color='blue', alpha=0.4)
plt.scatter(x_GKV, y_GKV-1, color='blue', alpha=0.4)
plt.scatter(x_GKV-0.7, y_GKV-0.7, color='blue', alpha=0.4)
plt.scatter(x_GKV-1, y_GKV, color='blue', alpha=0.4)
plt.scatter(x_GKV-0.7, y_GKV+0.7, color='blue', alpha=0.4)
plt.scatter(1000, 1000, color='blue', alpha=0.4, label='Alternative Goalkeeper Positions')

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')
# Plot line between shot position and left goalpost
x_values = [x_SV, x_LV]
y_values = [y_SV, y_LV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed', label='Shooting Cone')
# Plot line between shot position and right goalpost
x_values = [x_SV, x_RV]
y_values = [y_SV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, linestyle='dashed')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/alternative_positions.png')
plt.show()

# %% [markdown]
# Goalkeeper's arc:

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)')
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
x_gkv_ga, y_gkv_ga = 41.78, 3.58
plt.scatter(x_gkv_ga, y_gkv_ga, color='blue', alpha=0.8, label='Goalkeeper Position (G)')
plt.text(x_gkv_ga+0.5, y_gkv_ga, 'G', fontsize=20)
# Plot goal middle
plt.scatter(x_MV, y_MV, color='green', alpha=0.8, label='Middle of the Goal (M)')
plt.text(x_MV+0.3, y_MV-1, 'M', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot gk arc
plt.gca().plot(x_MV, y_MV, 'o', ms=186, mec='blue', mfc='none', alpha=0.4, mew=2)
x = np.linspace(100, 100, 100)
y = m_bisector*x + q_bisector
plt.plot(x, y, color='blue', alpha=0.4, label='Goalkeeper\'s Arc')

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')

# Plot bisector
m_ballline = (y_SV-y_MV)/(x_SV-x_MV)
q_ballline = y_SV - m_ballline*x_SV
x = np.linspace(-5, 100, 100)
y = m_ballline*x + q_ballline
plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Ball Line (SM)')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/gk_arc.png')
plt.show()

# %% [markdown]
# Line positioning:

# %%
# Apply function
vertical_pitch()

# Plot shot position
plt.scatter(x_SV, y_SV, color='red', alpha=0.8, label='Shooting Position (S)')
plt.text(x_SV+0.5, y_SV, 'S', fontsize=20)
# Plot gk position
x_gkv_lp, y_gkv_lp = 40.97, 2
plt.scatter(x_gkv_lp, y_gkv_lp, color='blue', alpha=0.8, label='Goalkeeper Position (G)')
plt.text(x_gkv_lp+0.5, y_gkv_lp+0.2, 'G', fontsize=20)
# Plot goal middle
plt.scatter(x_MV, y_MV, color='green', alpha=0.8, label='Middle of the Goal (M)')
plt.text(x_MV+0.3, y_MV-1, 'M', fontsize=20)
# Plot left goalpoast
plt.scatter(x_LV, y_LV, color='red', alpha=0.8)
plt.text(x_LV-0.8, y_LV-1, 'L', fontsize=20)
# Plot right goalpoast
plt.scatter(x_RV, y_RV, color='red', alpha=0.8)
plt.text(x_RV+0.3, y_RV-1, 'R', fontsize=20)

# Plot goal line
x_values = [-5, 85]
y_values = [2, 2]
plt.plot(x_values, y_values, color='blue', alpha=0.4, label='Goalkeeper Line')

# Plot goal line
x_values = [x_LV, x_RV]
y_values = [y_LV, y_RV]
plt.plot(x_values, y_values, color='red', alpha=0.4, label='Goal Line (LR)')

# Plot bisector
m_ballline = (y_SV-y_MV)/(x_SV-x_MV)
q_ballline = y_SV - m_ballline*x_SV
x = np.linspace(-5, 100, 100)
y = m_ballline*x + q_ballline
plt.plot(x, y, color='green', alpha=0.4, linestyle='dashed', label='Ball Line (SM)')

# Plot legend
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/line_positioning.png')
plt.show()

# %% [markdown]
# KNN:

# %%
# Copy 1v1 dataframe
df = df_1v1.copy()
# Create empty list
ls_distance = []

# Define row
i = 14        
# Define shot coordinates
x_shot = df.at[i, 'x_shot']
y_shot = df.at[i, 'y_shot']

# Iterate over all rows in dataframe
for row in range(0, len(df)):
    # Define similar shot coordinates
    x_shot_similar = df.at[row, 'x_shot']
    y_shot_similar = df.at[row, 'y_shot']
    # Add distance between shot and similar shot to list
    ls_distance.append(math.dist([x_shot, y_shot], [x_shot_similar, y_shot_similar]))
# Sort indices by ascending distance values and save value 1 to 21 (don't save the smallest)
sorted_indices = np.argsort(ls_distance).tolist()[1:21]

# Define counter variables
x_gk_tot = 0
y_gk_tot = 0
# Sum up 20 x_gk and y_gk coordinates from 20 most similar shots
for row in sorted_indices:
    x_gk_tot = x_gk_tot + df.at[row, 'x_gk']
    y_gk_tot = y_gk_tot + df.at[row, 'y_gk']
# Calculate average gk position
x_gk_avg = x_gk_tot/20
y_gk_avg = y_gk_tot/20

# %%
# Apply function
vertical_pitch()

# Iterate over all 20 similar shot positions
for i in sorted_indices:
    # Plot similar shot positions
    x_shot_similar = df.at[i, 'y_shot']       # Transformation from horizontal y to vertical x   
    y_shot_similar = 120 - df.at[i, 'x_shot'] # Transformation from horizontal x to vertical y
    plt.scatter(x_shot_similar, y_shot_similar, color='red', alpha=0.8)
    # Plot similar gk positions
    x_gk_similar = df.at[i, 'y_gk']
    y_gk_similar = 120 - df.at[i, 'x_gk']
    # Change gk position color for goals
    if df.at[i, 'outcome'] == 'Goal':
        color = 'orange'
    else:
        color = 'blue'
    plt.scatter(x_gk_similar, y_gk_similar, color=color, alpha=0.8)

# Create labels for legend
plt.scatter(1000, 1000, color='red', alpha=0.8, label='Shots')
plt.scatter(1000, 1000, color='orange', alpha=0.8, label='Goalkeeper Positions (Goals)')
plt.scatter(1000, 1000, color='blue', alpha=0.8, label='Goalkeeper Positions (No-Goals)')
plt.scatter(y_gk_avg, 120-x_gk_avg, marker='x', s=200, color='green', alpha=0.8, label='Average Goalkeeper Position')

# Plot legend and scale plot
plt.legend(loc='upper left', prop={'size': 20})
# Save and show plot
plt.savefig('images/knn.png')
plt.show()

# %% [markdown]
# ### Individual Goalkeeper Analysis
# Correlations: https://towardsdatascience.com/rbo-v-s-kendall-tau-to-compare-ranked-lists-of-items-8776c5182899
#
# Correlations: Kolmogorov-Smirnov test, comparing top-k lists [7]
#
# FUT: https://www.futhead.com/22/players/?group=gk&level=all_nif&bin_platform=ps
#
# 12Jul: https://www.fifacm.com/

# %% [markdown]
# Create individual goalkeeper dataframe:

# %%
# Define dataframes
df = df_1v1.copy()
df_id = df[['goalkeeper', 'goalkeeper_id']].sort_values(by = ['goalkeeper'], ascending = True).drop_duplicates().reset_index(drop = True)
df_shots = df[['outcome', 'goalkeeper']].groupby(by=['goalkeeper'], dropna = False).count()
df_xg = df[['statsbomb_xg', 'goalkeeper']].groupby(by=['goalkeeper'], dropna = False).sum()
df_outcome = df[['outcome', 'goalkeeper']].where(df['outcome'] == 'Goal').dropna().groupby(by=['goalkeeper'], dropna = False).count()
df_distance_gk_gk_avg = df[['distance_gk_gk_avg', 'goalkeeper']].groupby(by=['goalkeeper'], dropna = False).mean()
df_distance_gk_bisector = df[['distance_gk_bisector', 'goalkeeper']].groupby(by=['goalkeeper'], dropna = False).mean()
# Convert gk id from float to int
df_id = df_id.astype({'goalkeeper_id': int})
# Create empty lists
ls_gk = sorted(df['goalkeeper'].unique().tolist())
ls_id = df_id['goalkeeper_id'].tolist()
ls_shots = []
ls_xg = []
ls_outcome = []
ls_distance_gk_gk_avg = []
ls_distance_gk_bisector = []

# Iterate over all rows in dataframe
for row in range(0, len(df_id)):
    # Add values to lists
    ls_shots.append(df_shots['outcome'][row])
    ls_xg.append(round(df_xg['statsbomb_xg'][row], 2))
    ls_outcome.append(df_outcome['outcome'][row])
    ls_distance_gk_bisector.append(round(df_distance_gk_bisector['distance_gk_bisector'][row], 4))
    ls_distance_gk_gk_avg.append(round(df_distance_gk_gk_avg['distance_gk_gk_avg'][row], 4))

# Create empty dataframe and add complete lists 
df_gsaa = pd.DataFrame()
df_gsaa['fifa22_fut_rating'] = [76, 70, 74, 70, 82, 89, 75, 87, 83, 85, 83, 76, 90, 81, 75, 85, 76, 82, 75, 89, 81, 82, 79, 87, 85]
df_gsaa['fifa21_12jul_rating'] = [76, 70, 74, 72, 81, 86, 74, 87, 80, 85, 83, 74, 90, 82, 72, 85, 77, 83, 73, 89, 81, 80, 78, 87, 84]
df_gsaa['goalkeeper'] = ls_gk
df_gsaa['goalkeeper_id'] = ls_id
df_gsaa['sum_shots'] = ls_shots
df_gsaa['sum_xg'] = ls_xg
df_gsaa['sum_goals'] = ls_outcome
df_gsaa['gsaa'] = df_gsaa['sum_xg'] - df_gsaa['sum_goals']
df_gsaa['gsaa_per_shot'] = round(df_gsaa['gsaa'] / df_gsaa['sum_shots'], 4)
df_gsaa['mean_distance_gk_bisector'] = ls_distance_gk_bisector
df_gsaa['mean_distance_gk_gk_avg'] = ls_distance_gk_gk_avg

# Sort dataframes
df_rating = df_gsaa.sort_values(by = ['fifa21_12jul_rating'], ascending=False).reset_index(drop = True)
df_gsaa = df_gsaa.sort_values(by = ['gsaa_per_shot'], ascending=False).reset_index(drop = True)
df_distance_gk_gk_avg = df_gsaa.sort_values(by = ['mean_distance_gk_gk_avg'], ascending = True).reset_index(drop = True)
df_distance_gk_bisector = df_gsaa.sort_values(by = ['mean_distance_gk_bisector'], ascending = True).reset_index(drop = True)
# Save lists with gk ids
ls_rating = df_rating['goalkeeper_id'].tolist()
ls_gsaa = df_gsaa['goalkeeper_id'].tolist()
ls_gk_gk_avg = df_distance_gk_gk_avg['goalkeeper_id'].tolist()
ls_gk_bisector = df_distance_gk_bisector['goalkeeper_id'].tolist()
# Save lists with gk names
ls_rating_names = df_rating['goalkeeper'].tolist()
ls_gsaa_names = df_gsaa['goalkeeper'].tolist()
ls_gk_gk_avg_names = df_distance_gk_gk_avg['goalkeeper'].tolist()
ls_gk_bisector_names = df_distance_gk_bisector['goalkeeper'].tolist()

# Sort and display dataframe
df_gk = df_gsaa.sort_values(by = ['gsaa_per_shot'], ascending=False).reset_index(drop = True)
df_gk

# %% [markdown]
# Messi test:

# %%
ls_gsaa_top = df_gsaa.where(df_gsaa['fifa21_12jul_rating'] > 85).dropna().index.tolist()
ls_gk_gk_avg_top = df_distance_gk_gk_avg.where(df_distance_gk_gk_avg['fifa21_12jul_rating'] > 85).dropna().index.tolist()
ls_gk_bisector_top = df_distance_gk_bisector.where(df_distance_gk_bisector['fifa21_12jul_rating'] > 85).dropna().index.tolist()

ls_gsaa_top_new = [x+1 for x in ls_gsaa_top]
ls_gk_gk_avg_top_new = [x+1 for x in ls_gk_gk_avg_top]
ls_gk_bisector_top_new = [x+1 for x in ls_gk_bisector_top]

mean_gsaa = mean(ls_gsaa_top_new)
mean_gk_gk_avg = mean(ls_gk_gk_avg_top_new)
mean_gk_bisector = mean(ls_gk_bisector_top_new)

print(mean_gsaa, mean_gk_gk_avg, mean_gk_bisector)

# %% [markdown]
# Pearson correlation (works only for lists with ints):

# %%
print('Pearson NumPy:', np.corrcoef(ls_gsaa, ls_gk_gk_avg)[0, 1])
print('Pearson SciPy:', pearsonr(ls_gsaa, ls_gk_gk_avg)[0])

# %%
print('gsaa and gk_gk_avg:', round(np.corrcoef(ls_gsaa, ls_gk_gk_avg)[0, 1], 4))
print('gsaa and gk_bisector:', round(np.corrcoef(ls_gsaa, ls_gk_bisector)[0, 1], 4))
print('rating and gk_gk_avg:', round(np.corrcoef(ls_rating, ls_gk_gk_avg)[0, 1], 4))
print('rating and gk_bisector:', round(np.corrcoef(ls_rating, ls_gk_bisector)[0, 1], 4))

# %% [markdown]
# Kendall Tau (works for list with ints as well as strings, but different results???):

# %%
tau, p_value = stats.kendalltau(ls_gsaa, ls_gk_gk_avg)
print('gsaa and gk_gk_avg:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_gsaa, ls_gk_bisector)
print('gsaa and gk_bisector:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_rating, ls_gk_gk_avg)
print('rating and gk_gk_avg:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_rating, ls_gk_bisector)
print('rating and gk_bisector:', round(tau, 4))

# %%
tau, p_value = stats.kendalltau(ls_gsaa_names, ls_gk_gk_avg_names)
print('gsaa and gk_gk_avg:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_gsaa_names, ls_gk_bisector_names)
print('gsaa and gk_bisector:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_rating_names, ls_gk_gk_avg_names)
print('rating and gk_gk_avg:', round(tau, 4))
tau, p_value = stats.kendalltau(ls_rating_names, ls_gk_bisector_names)
print('rating and gk_bisector:', round(tau, 4))

# %%
ls_abc_1 = ['s6e17', 's2e10', 's3e15', 's3e24', 's3e25']
ls_abc_2 = ['s6e17', 's2e10', 's3e24', 's3e25', 's3e15']

ls_123_1 = [1, 2, 3, 4, 5]
ls_123_2 = [1, 2, 4, 5, 3]

print(stats.kendalltau(ls_abc_1, ls_abc_2))
print(stats.kendalltau(ls_123_1, ls_123_2))

# %% [markdown]
# RBO (works for list with ints as well as strings, same results):

# %%
def rbo(list1, list2, p = 0.9):
   # tail recursive helper function
   def helper(ret, i, d):
       l1 = set(list1[:i]) if i < len(list1) else set(list1)
       l2 = set(list2[:i]) if i < len(list2) else set(list2)
       a_d = len(l1.intersection(l2))/i
       term = math.pow(p, i) * a_d
       if d == i:
           return ret + term
       return helper(ret + term, i + 1, d)
   k = max(len(list1), len(list2))
   x_k = len(set(list1).intersection(set(list2)))
   summation = helper(0, 1, k)
   return round(((float(x_k)/k) * math.pow(p, k)) + ((1-p)/p * summation), 4)

# Example usage
print('gsaa and gk_gk_avg:', rbo(ls_gsaa, ls_gk_gk_avg))
print('gsaa and gk_bisector:', rbo(ls_gsaa, ls_gk_bisector)) 
print('ratings and gk_gk_avg:', rbo(ls_rating, ls_gk_gk_avg))
print('ratings and gk_bisector:', rbo(ls_rating, ls_gk_bisector))

# %%
p = 0.9
d = 25

def sum_series(p, d):
   # tail recursive helper function
   def helper(ret, p, d, i):
       term = math.pow(p, i)/i
       if d == i:
           return ret + term
       return helper(ret + term, p, d, i+1)
   return helper(0, p, d, 1)

wrbo1_d = 1 - math.pow(p, d-1) + (((1-p)/p) * d *(np.log(1/(1-p)) - sum_series(p, d-1)))

print(wrbo1_d) # Output: 0.8555854467473518

# %% [markdown]
# Plots:

# %%
# Plot one column on x and y axis each and add linreg line
def plot_xy_linreg(df, x_axis, y_axis):
    
    # From column to list to array
    x = np.array(df[x_axis].tolist())
    y = np.array(df[y_axis].tolist())

    # Create scatter plot
    plt.plot(x, y, 'o')
    # Add axis label
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)
    
    # Define m = slope and b = intercept
    m, b = np.polyfit(x, y, 1)
    # Add line of best fit
    plt.plot(x, m*x + b)

# %%
plot_xy_linreg(df_gsaa, 'gsaa', 'mean_distance_gk_bisector')

# %%
plot_xy_linreg(df_gsaa, 'gsaa', 'sum_shots')

# %%
# Filter df_1v1 for one gk
df_yann = df_1v1.where(df_1v1['goalkeeper'] == 'Yann Sommer').dropna().reset_index(drop = True)
# Apply method for one gk and gk_avg
plot_deviation(df_yann, 'gk_avg', 'gk')
